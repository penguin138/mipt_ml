# %%
import numpy as np
import pandas as pd
from collections import namedtuple
from sklearn.linear_model import LinearRegression, Ridge
from sklearn.cross_validation import cross_val_score
from sklearn.feature_extraction.text import HashingVectorizer
from gensim.models.doc2vec import Doc2Vec, TaggedDocument

# %% [markdown]
# ## Идея
# В этом ноутбуке использовался gensim doc2vec и линейная регрессия. А именно, из urlов и title-ов делался bag of words для каждого id, затем это запихивалось в doc2vec, а на полученных векторах делалась линейная регрессия. К сожалению эта модель не сработала, она была хуже даже sample_solution, но зато сработал вариант c TfidfVectorizer и линейной регрессией(см. второй ipynb)

# %% [markdown]
# ## Подготовка данных

# %%
# urls_train
urls_train_df = pd.read_csv('kaggle_data/url_domain_train', header=None, delimiter='\t')
urls_train_df.columns = ['id', 'url', 'count']
urls_train_df = urls_train_df[['id', 'url']]
# urls_test
urls_test_df = pd.read_csv('kaggle_data/url_domain_test', header=None, delimiter='\t')
urls_test_df.columns = ['id', 'url', 'count']
urls_test_df = urls_test_df[['id', 'url']]

# %%
urls_train_df.head()
urls_test_df.head()
# Out:
#                                  id                          url
# 0  0000000151004FF4ADD746DA10685A01                    afisha.ru
# 1  0000000151004FF4ADD746DA10685A01                       aif.ru
# 2  0000000151004FF4ADD746DA10685A01  aimfar.solution.weborama.fr
# 3  0000000151004FF4ADD746DA10685A01                  alkotest.ru
# 4  0000000151004FF4ADD746DA10685A01                 aptekamos.ru

# %%
# urls_train
urls_train_df = pd.DataFrame(urls_train_df.groupby('id')['url'].apply(lambda x: x.tolist()))
urls_train_df['id'] = urls_train_df.index
urls_train_df.index = range(len(urls_train_df))
urls_train_df.columns = ['urls', 'id']
#urls_test
urls_test_df = pd.DataFrame(urls_test_df.groupby('id')['url'].apply(lambda x: x.tolist()))
urls_test_df['id'] = urls_test_df.index
urls_test_df.index = range(len(urls_test_df))
urls_test_df.columns = ['urls', 'id']

# %%
urls_train_df.head()
urls_test_df.head()
# Out:
#                                                 urls  \
# 0  [1000bankov.ru, 1tv.ru, 4put.ru, argumenti.ru,...
# 1  [autorambler.ru, bilettorg.ru, dsol-druzhba.ru...
# 2                        [photosight.ru, rambler.ru]
# 3  [base.consultant.ru, dogovor-obrazets.ru, fd.r...
# 4  [assessor.ru, audit-it.ru, base.garant.ru, com...
#
#                                  id
# 0  000000014A02348E701552980349FF01
# 1  000000014A10EA183BF8594A0B2AB201
# 2  000000014A4FE5C33A929D4C26943601
# 3  000000014B7BB9957784A9BC0AC9F401
# 4  000000014C7749F896D82C2B01E8B801

# %%
age_train_df = pd.read_csv('kaggle_data/age_profile_train', header=None, delimiter='\t')
age_train_df.columns = ['id', 'age']

# %%
age_train_df.head()
# Out:
#                                  id  age
# 0  000000013CB5719C0000A2C90002C101   53
# 1  00000001442BE24000001B7D00F50801   48
# 2  00000001448580F800003F1B31FB0901   28
# 3  0000000145BDB2FF000157971645E901   44
# 4  000000014602771F0000DB9359714C01   48

# %%
train_df = urls_train_df.merge(age_train_df, on='id', how='left')

# %%
train_df.head()
# Out:
#                                                 urls  \
# 0            [id.rambler.ru, mail.rambler.ru, r0.ru]
# 1  [1prime.ru, autorambler.ru, chellak.ru, docs.c...
# 2                                 [bosch-korolev.ru]
# 3  [aptekanizkihcen.ua, colady.ru, gorod.dp.ua, i...
# 4  [astrorok.ru, diets.ru, edaplus.info, eshzdoro...
#
#                                  id  age
# 0  000000013CB5719C0000A2C90002C101   53
# 1  00000001442BE24000001B7D00F50801   48
# 2  00000001448580F800003F1B31FB0901   28
# 3  0000000145BDB2FF000157971645E901   44
# 4  000000014602771F0000DB9359714C01   48

# %%
title_train_df = pd.read_csv('kaggle_data/title_unify_train', header=None,delimiter='\t')
title_test_df = pd.read_csv('kaggle_data/title_unify_test', header=None,delimiter='\t')

# %%
# title train
title_train_df.columns = ['id', 'title', 'count']
title_train_df = title_train_df[['id', 'title']]
# title test
title_test_df.columns = ['id', 'title', 'count']
title_test_df = title_test_df[['id', 'title']]
title_train_df.head()
title_test_df.head()
# Out:
#                                  id  \
# 0  0000000151790DCC1E8322AF0B6FA701
# 1  0000000151790DCC1E8322AF0B6FA701
# 2  0000000151790DCC1E8322AF0B6FA701
# 3  0000000151790DCC1E8322AF0B6FA701
# 4  0000000151790DCC1E8322AF0B6FA701
#
#                                                title
# 0  20-километровый амур китай мост недвижимость п...
# 1  24-х 34-х до договор неделя новость предложить...
# 2  3xl armour compress heatgear long size sleev s...
# 3  4-е ca зачёт медальный место новость ои-2012 п...
# 4  4-колёсный moi-bebik oregon oscar ru коляска к...

# %%
# title train
title_train_df = pd.DataFrame(title_train_df.groupby('id')['title'].apply(lambda f: f.tolist()))
title_train_df.columns = ['titles']
# title test
title_test_df = pd.DataFrame(title_test_df.groupby('id')['title'].apply(lambda f: f.tolist()))
title_test_df.columns = ['titles']

# %%
# title train
title_train_df['id'] = title_train_df.index
title_train_df.index = range(len(title_train_df))
title_train_df.columns = ['titles', 'id']
# title test
title_test_df['id'] = title_test_df.index
title_test_df.index = range(len(title_test_df))
title_test_df.columns = ['titles', 'id']
title_train_df.head()
title_test_df.head()
# Out:
#                                               titles  \
# 0  [11-й гектар дом коммунизм на набережная недос...
# 1  [20-летний выглядеть девушка как королева ната...
# 2                          [медийный портал рамблер]
# 3  [бесплатно код онлайн срочно статистика, или и...
# 4  [bank privat автокредитование банковский банко...
#
#                                  id
# 0  000000014A02348E701552980349FF01
# 1  000000014A10EA183BF8594A0B2AB201
# 2  000000014A4FE5C33A929D4C26943601
# 3  000000014B7BB9957784A9BC0AC9F401
# 4  000000014C7749F896D82C2B01E8B801

# %%
train_df = title_train_df.merge(train_df,on='id')
test_df = title_test_df.merge(urls_test_df,on='id')
# train_df = train_df[['id', 'titles', 'urls', 'age']]
train_df.head()
test_df.head()
# Out:
#                                               titles  \
# 0  [11-й гектар дом коммунизм на набережная недос...
# 1  [20-летний выглядеть девушка как королева ната...
# 2                          [медийный портал рамблер]
# 3  [бесплатно код онлайн срочно статистика, или и...
# 4  [bank privat автокредитование банковский банко...
#
#                                  id  \
# 0  000000014A02348E701552980349FF01
# 1  000000014A10EA183BF8594A0B2AB201
# 2  000000014A4FE5C33A929D4C26943601
# 3  000000014B7BB9957784A9BC0AC9F401
# 4  000000014C7749F896D82C2B01E8B801
#
#                                                 urls
# 0  [1000bankov.ru, 1tv.ru, 4put.ru, argumenti.ru,...
# 1  [autorambler.ru, bilettorg.ru, dsol-druzhba.ru...
# 2                        [photosight.ru, rambler.ru]
# 3  [base.consultant.ru, dogovor-obrazets.ru, fd.r...
# 4  [assessor.ru, audit-it.ru, base.garant.ru, com...

# %% [markdown]
# ## Снижение размерности

# %%
X = np.array(list(map(lambda x: x[0] + x[1],zip(train_df.urls.values,train_df.titles.values))))
X_test = np.array(list(map(lambda x: x[0] + x[1],zip(test_df.urls.values,test_df.titles.values))))

# %%
y = train_df.age.values

# %%
Z = list(map(lambda x: list(map(lambda y: y.split(" "), x)), X)) # split internal phrases into words
Z_test = list(map(lambda x: list(map(lambda y: y.split(" "), x)), X_test))

# %%
T = list(map(lambda l :[item for sublist in l for item in sublist], Z)) # flatten internal lists of lists
T_test = list(map(lambda l :[item for sublist in l for item in sublist], Z_test))

# %%
Y = list(map(lambda x: TaggedDocument(words=x[1],tags=[x[0]]),enumerate(list(T)))) # create TaggedDocuments for doc2vec
Y_test = list(map(lambda x: TaggedDocument(words=x[1],tags=[len(Y) + x[0]]),enumerate(list(T_test))))

# %%
print(np.array(Y))
# Out:
# [[ ['id.rambler.ru', 'mail.rambler.ru', 'r0.ru', 'бесплатный', 'надёжный', 'почта', 'рамблер', 'электронный', 'поиск', 'рамблер', 'профиль', 'чемпионат']
#   [0]]
#  [ ['1prime.ru', 'autorambler.ru', 'chellak.ru', 'docs.cntd.ru', 'echo.msk.ru', 'expert.ru', 'finance.rambler.ru', 'forbes.ru', 'forum.ixbt.com', 'garant.ru', 'govoritmoskva.ru', 'kommersant.ru', 'kp.ru', 'lenta.ru', 'mait.ru', 'metronews.ru', 'mk.ru', 'news.rambler.ru', 'news.smi2.ru', 'norm-load.ru', 'pfr.kirov.ru', 'pfrf.ru', 'photography-on-the.ru', 'realty.rambler.ru', 'ren.tv', 'riafan.ru', 'rns.online', 'rossbanki.ru', 'secretmag.ru', 'tehnorma.ru', 'tiu.ru', 'top68.ru', 'tvc.ru', 'tvzvezda.ru', 'vesti.ru', 'video.rambler.ru', 'weekend.rambler.ru', '24-х', '34-х', 'до', 'договор', 'неделя', 'новость', 'предложить', 'рабочий', 'рамблер', 'россиянин', 'сократить', 'трудовой', 'часы', 'al-hayat', 'new', 'rambler', 'servic', 'асад', 'договорённость', 'из', 'между', 'отъезд', 'рф', 'сирия', 'сообщить', 'сша', 'al-hayat', 'асад', 'договорённость', 'из', 'между', 'новость', 'отъезд', 'рамблер', 'рф', 'сирия', 'сообщить', 'сша', 'bloomberg', 'аналитик', 'год', 'ес', 'контрсанкция', 'март', 'мнение', 'на', 'назвать', 'новость', 'от', 'последний', 'пострадать', 'прогноз', 'россия', 'самый', 'сегодня', 'страна', 'эксперт', 'bloomberg', 'ес', 'контрсанкция', 'назвать', 'новость', 'от', 'пострадать', 'рамблер', 'россия', 'самый', 'страна', 'boe', 'new', 'rambler', 'servic', 'версия', 'крушение', 'неисправность', 'основный', 'ошибка', 'пилотирование', 'стать', 'технический', 'boe', 'версия', 'крушение', 'неисправность', 'новость', 'основный', 'ошибка', 'пилотирование', 'рамблер', 'стать', 'технический', 'boe', 'диспетчер', 'запись', 'новость', 'опубликовать', 'переговоры', 'пилот', 'разбиться', 'рамблер', 'boe', 'новость', 'пилот', 'последний', 'разбиться', 'рамблер', 'расшифровать', 'ростове-на-дону', 'слово', 'carlsberg', 'new', 'rambler', 'servic', 'гендиректор', 'полупустой', 'российский', 'рынок', 'сравнить', 'стакан', 'carlsberg', 'гендиректор', 'новость', 'полупустой', 'рамблер', 'российский', 'рынок', 'сравнить', 'стакан', 'cк', 'кража', 'новость', 'представитель', 'приватизация', 'рамблер', 'сравнить', 'юкос', 'cледственный', 'new', 'rambler', 'servic', 'комитет', 'кража', 'приватизация', 'сравнить', 'юкос', 'eiu', 'new', 'rambler', 'servic', 'аналитика', 'внешний', 'второй', 'глобальный', 'место', 'на', 'политика', 'поставить', 'риск', 'россия', 'среди', 'eiu', 'аналитика', 'внешний', 'второй', 'глобальный', 'место', 'на', 'новость', 'политика', 'поставить', 'рамблер', 'риск', 'россия', 'среди', 'facebook', 'заблокировать', 'земфира', 'лоза', 'новость', 'после', 'пост', 'про', 'публикация', 'рамблер', 'страница', 'юрий', 'flydubai', 'авиакомпания', 'агентство', 'информация', 'который', 'лайнер', 'новость', 'прайма', 'разбиться', 'ростове-на-дону', 'справка', 'экономический', 'forb', 'ru', 'долларовый', 'миллионер', 'оказаться', 'отток', 'по', 'россия', 'страна', 'топ-10', 'forb', 'ru', 'министр', 'ночное', 'подробность', 'путин', 'сми', 'совещание', 'узнать', 'garant', 'ru', 'www', 'использование', 'материал', 'портал', 'правило', 'сайт', 'lada', 'priora', 'vesta', 'автомобильный', 'авторамблер', 'журнал', 'на', 'немного', 'онлайн', 'от', 'получить', 'супердешёвый', 'lada', 'priora', 'vesta', 'немного', 'новость', 'от', 'получить', 'рамблер', 'супердешёвый', 'lenta', 'ru', 'антироссийский', 'банк', 'всемирный', 'госэкономика', 'дата', 'назвать', 'отмена', 'санкция', 'финансы', 'lighroom', 'lightroom', 'photoshop', 'для', 'начинающий', 'новичок', 'обработка', 'пейзаж', 'портрет', 'урок', 'metro', 'вильнюс', 'земфира', 'инцидент', 'концерт', 'на', 'прокомментировать', 'украина', 'флаг', 'new', 'rambler', 'servic', 'активность', 'вырасти', 'деловой', 'до', 'индекс', 'пункт', 'россия', 'сфера', 'услуга', 'new', 'rambler', 'servic', 'бангкок', 'медведев', 'пройти', 'работа', 'фотовыставка', 'new', 'rambler', 'servic', 'баррель', 'ближний', 'ввп', 'время', 'вшэ', 'за', 'на', 'не', 'нефть', 'ожидать', 'около', 'при', 'россия', 'рост', 'цена', 'new', 'rambler', 'servic', 'берег', 'вблизи', 'война', 'впервые', 'время', 'заметить', ' ...
#   [1]]
#  [ ['bosch-korolev.ru', 'авто', 'бош', 'контакт', 'королёв', 'сервис', 'авто', 'бош', 'королёв', 'сервис']
#   [2]]
#  ...,
#  [ ['aif.ru', 'autochel.ru', 'chelyabinsk.ru', 'id.rambler.ru', 'khl.ru', 'm.rambler.ru', 'm.rsport.ru', 'mail-pda.rambler.ru', 'news.rambler.ru', 'pnevmoshop.ru', '4z7616051a', '4z7616051d', '4z7616052a', 'allroad', 'arnott', 'audi', 'ауди', 'бмв', 'мерседес', 'олроуд', 'пневмобаллон', 'пневмоподвеска', 'подвеска', 'элемент', 'американец', 'быть', 'весь', 'главное', 'жить', 'интервью', 'куинт', 'наполовину', 'новость', 'р-спорт', 'русский', 'себя', 'спорт', 'считать', 'челябинск', 'аргумент', 'карибский', 'кино', 'культура', 'маккартни', 'море', 'пират', 'половина', 'сняться', 'факт', 'весь', 'взять', 'главное', 'за', 'новость', 'очень', 'поражение', 'прошлое', 'р-спорт', 'реванш', 'сезон', 'ска', 'спорт', 'хоккеист', 'хоккей', 'хотеть', 'цска', 'юрзиновый', 'весь', 'главное', 'новость', 'р-спорт', 'спорт', 'весь', 'главное', 'новость', 'спорт', 'хоккей', 'восстановление', 'доступ', 'игра', 'континентальный', 'кхл', 'лига', 'мг', 'металлург', 'протокол', 'сибирь', 'хоккейный', 'континентальный', 'лига', 'по', 'россия', 'хоккей', 'хоккейный', 'чемпионат', 'мвд', 'некоторый', 'новость', 'посещение', 'предложить', 'рамблер', 'россиянин', 'согласовывать', 'страна', 'медийный', 'портал', 'рамблер']
#   [114087]]
#  [ ['blog.partisani.ge', 'li.ru', 'tvrain.ru', 'ru', 'онлайн', 'попка', 'порно', 'секс', 'азербайджан', 'военный', 'гибель', 'карабах', 'нагорный', 'свой', 'сообщить', 'воскресение', 'группа', 'крым', 'лидер', 'оккупировать', 'прокомментировать', 'свой', 'слово', 'капитолий', 'назвать', 'полиция', 'преступление', 'стрельба', 'уголовный', 'ларёк', 'наносить', 'ответный', 'удар']
#   [114088]]
#  [ ['doctorkirov.ru', 'drive.ru', 'extrim-park43.ru', 'm.regions.pulset.ru', 'mail-pda.rambler.ru', 'reso.ru', 'sberbank.ru', '5d', 'merced-benz', 'видео', 'драйв', 'комплектация', 'отзыв', 'тест-драйв', 'форум', 'фото', 'цена', 'amg', 'coup', 'gle', 'merced-benz', 'видео', 'драйв', 'комплектация', 'отзыв', 'тест-драйв', 'форум', 'фото', 'цена', 'amg', 'gl', 'merced-benz', 'видео', 'драйв', 'комплектация', 'отзыв', 'тест-драйв', 'форум', 'фото', 'цена', 'amg', 'gt', 'merced-benz', 'видео', 'драйв', 'комплектация', 'отзыв', 'тест-драйв', 'форум', 'фото', 'цена', 'amg', 'merced-benz', 'видео', 'драйв', 'комплектация', 'отзыв', 'тест-драйв', 'форум', 'фото', 'цена', 'cla', 'merced-benz', 'видео', 'драйв', 'комплектация', 'отзыв', 'тест-драйв', 'форум', 'фото', 'цена', 'gl', 'merced-benz', 'видео', 'драйв', 'комплектация', 'отзыв', 'тест-драйв', 'форум', 'фото', 'цена', 'maybach', 'merced-benz', 'видео', 'драйв', 'комплектация', 'отзыв', 'тест-драйв', 'форум', 'фото', 'цена', 'merced-benz', 'saloon', 'видео', 'драйв', 'комплектация', 'отзыв', 'тест-драйв', 'форум', 'фото', 'цена', 'merced-benz', 'видео', 'драйв', 'комплектация', 'отзыв', 'тест-драйв', 'форум', 'фото', 'цена', 'аптека', 'доктор', 'киров', 'медицинский', 'портал', 'табекс', 'террапи', 'без', 'кредит', 'обеспечение', 'потребительский', 'сбербанк', 'драйв', 'калькулятор', 'калькулятор', 'осаго', 'квадроцикл', 'киров', 'прокат', 'кредит', 'потребительский', 'сбербанк']
#   [114089]]]

# %%
doc2vec = Doc2Vec(Y + Y_test, size=1000, window=8, min_count=5, workers=4)

# %%
np.array(doc2vec.docvecs).shape
# Out:
# (134045, 1000)

# %%
C = np.array(doc2vec.docvecs)[:len(Y)]
C_test = np.array(doc2vec.docvecs)[len(Y):]

# %% [markdown]
# ## Обучение модели

# %%
reg = LinearRegression()
- cross_val_score(reg, C, y, scoring='mean_squared_error')
# Out:
# array([ 156.78158219,  158.72334977,  139.46715202])

# %% [markdown]
# ## Отправка Решения

# %%
reg = LinearRegression()
reg.fit(C, y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
y_pred = reg.predict(C_test)

# %%
test_df['age'] = y_pred

# %%
test_df = test_df[['id', 'age']]
test_df.columns = ['Id', 'age']

# %%
test_df.head()
# Out:
#                                  Id        age
# 0  000000014A02348E701552980349FF01  34.695022
# 1  000000014A10EA183BF8594A0B2AB201  38.838226
# 2  000000014A4FE5C33A929D4C26943601  36.704433
# 3  000000014B7BB9957784A9BC0AC9F401  35.442907
# 4  000000014C7749F896D82C2B01E8B801  37.265491

# %%
random_sol = pd.read_csv('random_solution.csv')
miss_idx = set(random_sol.Id.values) - set(test_df.Id.values)
miss_df = pd.DataFrame(list(zip(list(miss_idx), np.ones(len(miss_idx)))))
miss_df.columns = ['Id', 'age']

# %%
test_df = test_df.append(miss_df, ignore_index=True)

# %%
test_df.to_csv('solution.csv', index=False)

# %%
# !wc -l solution.csv
# Out:
#    19980 solution.csv
