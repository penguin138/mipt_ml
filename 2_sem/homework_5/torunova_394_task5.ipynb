# %% [markdown]
# ## Check Questions
#
# **Вопрос 1**: Что такое backpropagation?
#
# Backpropagation -- этом метод подсчета градиента функции потерь по весам модели с помощью chain rule.
# Используется в нейросетях: каждый нейрон считает свои частные производные в forward pass-e, а потом они в обратном порядке перемножаются, чтобы получить итоговый градиент (так называемый backward pass).
#
#
# **Вопрос 2**: Какие активационные функции вы знаете?
#
# tanh(x), $\sigma(x) = \frac{1}{1 + \exp^{-x}}$, $rectifier(x) = \max(0, x)$
#
# **Вопрос 3**: Чем они интересны, почему среди множества всех возможных функций были выбраны именно эти?
#
# Эти функции нелинейные, поэтому можно аппроксимировать сложные зависимости, дифференцируемые (для backpropagation). Tanh и sigmoid выдают значения из [-1, 1] и [0, 1] соответственно, тем самым имитируя поведение нейронов в мозге. У tanh и sigmoid есть проблема -  vanishing gradients в очень глубоких сетях, т.к. очень маленькие производные, когда значения приближаются к 1.У ReLu нет такой проблемы.
#
# **Вопрос 4**: Чем deep learning отличается от обычных нейронных сетей?
#
# В deep neural networks много скрытых слоев, а в обычных нейронках 2-3 слоя.
#
# **Вопрос 5**: Что такое свертка?
#
# В применении к изображениям, это функция от какой-то части изображения, умножающая значения пикселей на веса и суммирующая результаты.
# **Вопрос 6**: Что такое скрытое состояние?
#
# Вектор, который хранится в RNN-cell и зависит от текущего входа и предыдущего своего значения. Таким образом RNN может учитывать предыдущий контекст.
#
# **Вопрос 7**: Что такое embedding?
#
# Embedding - map из токенов(слов, букв) в векторы размера hidden_size, которые являются уже входами rnn_cell-ов.

# %%
import tensorflow as tf
from tensorflow.python.ops import rnn_cell
from tensorflow.python.ops.math_ops import sigmoid, tanh
from scipy.ndimage.interpolation import shift
import numpy as np
import re
import string
from datetime import datetime
from bs4 import BeautifulSoup, Tag
import os

# %%
print(tf.__version__)
# Out:
# 0.11.0rc0

# %% [markdown]
# ### Utilities

# %%
class Vocabulary(object):
    """Vocabulary class."""

    __slots__ = ["word2index", "index2word", "unknown_idx", "charlevel"]

    def __init__(self, words=None, charlevel=False):
        """Init vocabulary."""
        self.word2index = {}
        self.index2word = []
        self.charlevel = charlevel
        # add unknown word/symbol:
        if not self.charlevel:
            self.add_words(["<UNK>"])
        else:
            self.add_words(["#"])
        self.unknown_idx = 0

        if words is not None:
            self.add_words(words)

    def add_words(self, words):
        """Add words to dictionary."""
        for word in words:
            if word not in self.word2index:
                self.word2index[word] = len(self.word2index)
                self.index2word.append(word)

    def __call__(self, line):
        """Convert from numerical representation to words and vice-versa."""
        if type(line) is np.ndarray:
            return " ".join([self.index2word[word_idx] for word_idx in line])
        if type(line) is list:
            if len(line) > 0:
                if line[0] is int:
                    return " ".join([self.index2word[word] for word in line])
            indices = np.zeros(len(line), dtype=np.int32)
        else:
            if not self.charlevel:
                tokens = re.split(r'\s+', line)
            else:
                tokens = list(line)
            indices = np.zeros(len(tokens), dtype=np.int32)

        for i, token in enumerate(tokens):
            indices[i] = self.word2index.get(token, self.unknown_idx)

        return indices

    @property
    def size(self):
        """Return length of vocabulary."""
        return len(self.index2word)

    def __len__(self):
        """Return length of vocabulary."""
        return len(self.index2word)


def pad_into_matrix(rows, padding=0):
    """Pad numerical rows with zeros so they all have the same width."""
    if len(rows) == 0:
        return np.array([0, 0], dtype=np.int32)
    lengths = list(map(len, rows))
    width = max(lengths)
    height = len(rows)
    mat = np.empty([height, width], dtype=rows[0].dtype)
    mat.fill(padding)
    for i, row in enumerate(rows):
        mat[i, 0:len(row)] = row
    return mat, lengths


def get_batches(numerical_lines, batch_size):
    """Generate batches of data."""
    current_batch_num = 0
    train_size = len(numerical_lines)
    while current_batch_num * batch_size < train_size:
        start = current_batch_num * batch_size
        end = (current_batch_num + 1) * batch_size
        lines_batch, lengths_batch = pad_into_matrix(numerical_lines[start:end])
        yield (lines_batch, lengths_batch,
               shift(lines_batch, shift=(0, -1)))
        current_batch_num += 1

def prepare_data(destination_file, *filenames):
    with open(destination_file, 'w') as parsed:
        all_texts = []
        for filename in filenames:
            # print(filename)
            soup = BeautifulSoup(open(filename), "html.parser")
            texts = map(Tag.getText, soup.findAll("body", text=True))
            # print(list(texts))
            parsed.write('\n'.join(texts))

# %% [markdown]
# ## Custom GRU
#
# Реализация GRU, как описано [здесь](http://colah.github.io/posts/2015-08-Understanding-LSTMs/).

# %%
class CustomGRUCell(rnn_cell.RNNCell):
    """Custom GRU implementation."""

    def __init__(self, hidden_size):
        """Init cell."""
        self.hidden_size = hidden_size

    def __call__(self, inputs, state, scope=None):
        """Compute GRU outputs."""
        # print("Starting GRU...")
        with tf.variable_scope(scope or "CustomGRUCell"):
            dim1 = inputs.get_shape()[1].__int__() + state.get_shape()[1].__int__()
            dim2 = inputs.get_shape()[1].__int__()
            # print("Initializing matrices...")
            W = tf.get_variable("W", [dim1, dim2],
                                initializer=tf.random_normal_initializer(0, np.sqrt(2.0 / dim1)))
            W_r = tf.get_variable("W_r", [dim1, dim2],
                                initializer=tf.random_normal_initializer(0, np.sqrt(2.0 / dim1)))
            W_z = tf.get_variable("W_z", [dim1, dim2],
                                initializer=tf.random_normal_initializer(0, np.sqrt(2.0 / dim1)))
            # print("Done.")
            z = sigmoid(tf.matmul(tf.concat(1, [state, inputs]), W_z))
            r = sigmoid(tf.matmul(tf.concat(1, [state, inputs]), W_r))
            new_state_candidate = tanh(tf.matmul(tf.concat(1, [r * state, inputs]), W))
            new_state = (1 - z) * state + z * new_state_candidate
            # print("Computed new states.")
            return new_state, new_state

    @property
    def state_size(self):
        """Return hidden state size."""
        return self.hidden_size

    @property
    def output_size(self):
        """Return output size of the cell."""
        return self.hidden_size

# %% [markdown]
# ## Model

# %%
class RnnLm(object):
    """Rnn language model class.

    Can be character-level or word-level.
    You can pass RNN hyperparameters to constructor.
    """

    log = None

    def __init__(self, filename=None, hidden_size=512, num_layers=3, batch_size=20,
                 num_epochs=200, num_tokens=20, charlevel=False, verbose=False, cell_type="lstm"):
        """Init hyperparameters or load existing model."""
        self.vocab = Vocabulary(charlevel=charlevel)
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        self.batch_size = batch_size
        self.num_epochs = num_epochs
        self.num_tokens = num_tokens
        self.charlevel = charlevel
        self.verbose = verbose
        self.cell_type = cell_type

    def print_(self, str_):
        if self.verbose:
            print(str_)

    def fit_data(self, filename):
        """Fit data to vocabulary."""
        self.print_("Loading data...")
        with open(filename) as text_file:
            lines = text_file.readlines()
        self.print_("Preparing data...")
        self.vocab = Vocabulary(charlevel=self.charlevel)
        for line in lines:
            if len(line) < 1000:
                if self.charlevel:
                    self.vocab.add_words(list(line))
                else:
                    self.vocab.add_words(line)
        self.numerical_lines = []
        for line in lines:
            self.numerical_lines.append(self.vocab(line))
        self.print_("Prepared data. Vocabulary size: {}".format(len(self.vocab)))

    def construct_graph(self):
        """Construct tensorflow graph."""
        num_items = len(self.vocab)
        self.print_("Building graph...")
        self.graph = tf.Graph()
        with self.graph.as_default():
            self.inputs = tf.placeholder(tf.int64, shape=(self.batch_size, None), name='inputs')
            self.labels = tf.placeholder(tf.int64, shape=(self.batch_size, None), name='labels')
            self.lengths = tf.placeholder(tf.int64, shape=(self.batch_size), name='lengths')
            self.hidden_states = []
            if self.cell_type == "lstm":
                hidden_state_size = 2*self.hidden_size
            elif self.cell_type == "gru":
                hidden_state_size = self.hidden_size
            else:
                raise ValueError("Unknown cell type!")
            for i in range(self.num_layers):
                self.hidden_states.append(tf.placeholder(tf.float32, shape=(1, hidden_state_size),
                                                         name='hidden_state{}'.format(i)))
            self.hidden_state = tuple(self.hidden_states)
            embeddings = tf.Variable(tf.random_uniform([num_items, self.hidden_size], -1.0, 1.0))
            # weights and bias for fully connected layer before softmax
            W = tf.Variable(tf.truncated_normal([self.hidden_size, num_items],
                                                stddev=np.sqrt(2.0 / self.hidden_size)))
            b = tf.Variable(tf.zeros([]))
            if self.cell_type == "lstm":
                cell = rnn_cell.LSTMCell(self.hidden_size, state_is_tuple=False)
            elif self.cell_type == "gru":
                cell = CustomGRUCell(self.hidden_size)
            else:
                raise ValueError("Unknown cell type!")
            rnn_multicell = rnn_cell.MultiRNNCell([cell] * self.num_layers)
            embedding = tf.nn.embedding_lookup(embeddings, self.inputs)
            self.token = tf.placeholder(tf.int64, shape=(1, 1), name="token")
            self.token_length = tf.placeholder(tf.int64, shape=(1), name="token_length")
            token_embedding = tf.nn.embedding_lookup(embeddings, self.token)
            with tf.variable_scope("dynamic_rnn") as scope:
                outputs, _ = tf.nn.dynamic_rnn(rnn_multicell, embedding, self.lengths,
                                               dtype=tf.float32, swap_memory=True)
                scope.reuse_variables()
                token_outputs, self.hidden_state = tf.nn.dynamic_rnn(rnn_multicell, token_embedding,
                                                                     self.token_length,
                                                                     initial_state=self.hidden_state,
                                                                     swap_memory=True)
            token_outputs = tf.reshape(token_outputs, [-1, self.hidden_size])
            token_logits = tf.matmul(token_outputs, W) + b
            self.token_probs = tf.nn.softmax(token_logits)
            outputs = tf.reshape(outputs, [-1, self.hidden_size])
            logits = tf.matmul(outputs, W) + b
            logits = tf.reshape(logits, [self.batch_size, -1, num_items])
            self.loss = (tf.reduce_sum(tf.nn.sparse_softmax_cross_entropy_with_logits(logits,
                                                                                      self.labels) *
                                       tf.to_float(tf.not_equal(self.labels, 0))) /
                         tf.to_float(tf.reduce_sum(tf.to_int32(tf.not_equal(self.labels, 0)))))
            self.optimizer = tf.train.AdamOptimizer().minimize(self.loss)
        self.print_("Graph construction done.")
        self.print_("Starting training...")

    def run_session(self):
        """Run tensorflow session with already constructed self.graph."""
        # self.session = tf.Session(graph=self.graph)
        with tf.Session(graph=self.graph) as session:
            tf.initialize_all_variables().run()
            for epoch in range(self.num_epochs):
                batch_number = 0
                batch_costs = []
                print("Starting epoch {}...".format(epoch))
                for (inputs_batch, lengths_batch, labels_batch) in get_batches(self.numerical_lines,
                                                                               self.batch_size):
                    if len(inputs_batch) < self.batch_size:
                        break
                    feedDict = {self.inputs: inputs_batch, self.lengths: lengths_batch,
                                self.labels: labels_batch}
                    self.print_("\tStarting batch {}...".format(batch_number))
                    start = datetime.now()
                    batch_cost, _ = session.run([self.loss, self.optimizer], feed_dict=feedDict)
                    batch_costs.append(batch_cost)
                    self.print_("\tDone batch {} in {} seconds.".format(batch_number,
                                                                        datetime.now()-start))
                    self.print_("\tCost: {}".format(batch_cost))
                    batch_number += 1
                if self.charlevel:
                    self.sample(" ", session=session)
                else:
                    self.sample("the", session=session)
                print("Done. Average cost: {}".format(np.average(batch_costs)))

    def train(self, filename):
        """Train rnn, using data in provided file."""
        self.fit_data(filename)
        self.construct_graph()
        self.run_session()

    def sample(self, token, num_tokens=None, session=None):
        """Sample tokens, starting with token."""
        created = False
        if session is None:
            raise ValueError("You should run train first.")
        if num_tokens is None:
            num_tokens = self.num_tokens
        print("Sampling...")
        start_word = token
        words = [start_word]
        if self.cell_type == "lstm":
            hidden_state_size = 2*self.hidden_size # because lstm has 2 hidden states
        elif self.cell_type == "gru":
            hidden_state_size = self.hidden_size
        else:
            raise ValueError("Unknown cell type!")
        hidden_states_ = tuple([np.zeros(shape=(1, hidden_state_size))] *
                               self.num_layers)

        for i in range(self.num_tokens):
            encoded_token = self.vocab(words[-1])
            if len(encoded_token.shape) > 1:
                new_token = [[encoded_token[0]]]
            else:
                new_token = [encoded_token]
            feedDict = {self.token: new_token, self.token_length: [1]}
            for i in range(self.num_layers):
                feedDict[self.hidden_states[i]] = hidden_states_[i]
            probabilities, hidden_states_ = session.run([self.token_probs,
                                                         self.hidden_state],
                                                        feed_dict=feedDict)
            next_word = np.random.choice(self.vocab.index2word, 1,
                                         p=probabilities[0])[0]
            words.append(next_word)
        if self.charlevel:
            print("".join(words))
        else:
            print(" ".join(words))

# %%
hidden_size = 200
num_layers = 3
batch_size = 500
num_epochs = 200

# %% [markdown]
# Будем использовать датасет [Reuters](http://www.daviddlewis.com/resources/testcollections/reuters21578/reuters21578.tar.gz). Распарсим тексты:

# %%
dirname = "reuters21578"
dest_file = "reuters_parsed.txt"
files = []
for filename in os.listdir(dirname):
    if filename[-4:] == ".sgm" and filename != "reut2-017.sgm": # for some reason beautifulsoup crashes on that file.
        # print(filename)
        files.append(os.path.join(dirname, filename))
prepare_data(dest_file, *sorted(files))

# %% [markdown]
# Потренируем character-level модель с LSTM, оптимизируя кросс-энтропию с помощью AdamOptimizer c дефолтными параметрами(у word-level почему-то получались exploding gradients, а с методом AdaDelta cost не уменьшался):

# %%
model = RnnLm(hidden_size=hidden_size, num_layers=num_layers, batch_size=batch_size, num_epochs=num_epochs,
              num_tokens=100, charlevel=True)
model.train("reuters_parsed.txt")
# Out:
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell.LSTMCell object at 0x7f336d9d8748>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Starting epoch 0...
# Sampling...
#     14..8 billion clodued.
#
#  The said.
#
#
#
#
#  Shode 7.16 vs discruce fustrees
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# . Torne
#
#
#
#
# Done. Average cost: 2.197575807571411
# Starting epoch 1...
# Sampling...
#     NMT       0.5 pct 802-23,278 vs 27,952,416-vs 50
#
#
#
#
#
#  10.7 mln
#
#  its
#
#
#
#
#
#
#
#
# 8 share reasured
#
#
#
# Done. Average cost: 1.5354686975479126
# Starting epoch 2...
# Sampling...
#     SOOitour ReIehverson explaring on were are is not planned
#
#
#
#
#
#
#
#
#  Flas
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 4
# .
# Done. Average cost: 1.3829985857009888
# Starting epoch 3...
# Sampling...
#     Shr 72 cts vs prote line rall for
#
#
#
#
#
#
#
#
#
#
#
#
# s
#
#
#
#
#
#
#
#
#
#
#
# /10,000
#
#
#
#
#
#
#
#
#
#
#
#
#
# 8
#
#
#
# 6
#
#
#  NOA  2.
# Done. Average cost: 1.309670329093933
# Starting epoch 4...
# Sampling...
#     It said the share requirements to range is
#  a troud-and Apde
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 8
# 8
# .78
#  mln
#
#
#
#
# Done. Average cost: 1.2629112005233765
# Starting epoch 5...
# Sampling...
#     Nine mths
#  replaced 1986 electric shares than a Health, a decline,
#
#
#
#
#
#
#
#
#
#
#
#
#
# 8 14.59
#
#
#
#
#  3.16
# Done. Average cost: 1.2292755842208862
# Starting epoch 6...
# Sampling...
#     Shr 24 cts vs 92 cts
#
#
#
#
#
#
#
#  dlrs
#
# 0
#
#
#
#
#
#
# 9.
#
#
#
# ,000
#
#
#
#
#
#
#
#
#
#
#
# 8
# -31,000
#
#
#
#
#
#
#
#
#
# 8,
# 0
#
#
#
#
#
#
#
#
#
# Done. Average cost: 1.203126072883606
# Starting epoch 7...
# Sampling...
#     Oper share a sech center this year, no news fiscal costs
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 85
#  two
#
#
#
#
#
#
#
#
#
# 'stor
#
#
# Done. Average cost: 1.182165265083313
# Starting epoch 8...
# Sampling...
#     The lawsworkers are remained the other furyly 10 tax trucks.
#
#
#
# "
#
#
#
#
#
#
#
#
#
#
# 9dlliement
#
#
#
#
#
#
#
#
#
# .
# Done. Average cost: 1.1644880771636963
# Starting epoch 9...
# Sampling...
#     Under nincludurap representing agreements in stability in
#
# 's
#
#
#
#
#
#
#
#
#  speed
#
#
#
#
#
#
#
#
#
# -00
#
#
#
#
#
#
#
#
# Done. Average cost: 1.1494172811508179
# Starting epoch 10...
# Sampling...
#                0
# 9 pct    1988   793.12  085.4    420-030.2
#
#
#
# 86
#
#    000
#
#
#
#
#    0.11     03
#
#
# Done. Average cost: 1.1361379623413086
# Starting epoch 11...
# Sampling...
#     But has inumuncually reached buyer destruction of South
#
#
#
#
#
#
#
#  Combined
#
#
#
#
#
#
#
#
#
#
# ,
#
#
# d
#
#
# ,
#
#
#
#
#
# Done. Average cost: 1.1244217157363892
# Starting epoch 12...
# Sampling...
#     Net 30,245,000 vs 377,000
#
#
#
#
#
#
# ..
#
# 4 15.2
#
#
#
#
#
#
#
#
#  140.26
#
#
#
#
#
#
#
#
#
#  12
# .9
#
#
#
#
#
#
#
#
# ,
# 668
#
#
#
# )
#
#
# 8
# Done. Average cost: 1.1138948202133179
# Starting epoch 13...
# Sampling...
#  Reuter
#
#             189.49    138.53   0.54     19.1
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  d
#
#
#
#
#
# .29
#
#
#
# .9
# Done. Average cost: 1.1042453050613403
# Starting epoch 14...
# Sampling...
#     "The latety its Federal Reserve is a acquer with a summa
#
#
#
#
#
#
#
#
#
#
#
#  We
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# m
#
#
#
#
#
#
# Done. Average cost: 1.0953541994094849
# Starting epoch 15...
# Sampling...
#     Seet approaches drives NSuibb, a premier of the negative
#
#
#
#
#
#
#
#
#
# .
# 2
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ppre
# Done. Average cost: 1.0871577262878418
# Starting epoch 16...
# Sampling...
#  Reuter
#
#  H. ROT. Ecuador, said the USXA, an agreement
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 5
# .6
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  had
#
#
#
# Done. Average cost: 1.0795682668685913
# Starting epoch 17...
# Sampling...
#     Shr 2.15 dlrs vs 1.71 dlrs
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# d
# dolle
#
#
#
#
#
#
#
#
#
#
# )
#
# ,
#
#
#
#
#
#
#
# )
#
#
#
#
#
#
#
# ).
#
#
#
#
#
#
#
# )
#
# Done. Average cost: 1.0725367069244385
# Starting epoch 18...
# Sampling...
#     Record Shulz said the pressure to give a good possible
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 6.25
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ,
#
#
# Done. Average cost: 1.0659610033035278
# Starting epoch 19...
# Sampling...
#     Shr 54 cts vs 18 cts
#
#
# 5
#
#
#
#
#
#
#
#  620.1
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ,
#
#
#
#
#
#
#
#
#
# durble
#
#
#
#
#
#
#
#
#
# )
#
# Done. Average cost: 1.0598772764205933
# Starting epoch 20...
# Sampling...
#     Avg shrs 4,995,000 vs 5,762,000
#
#
#
#  if
#
#
#  share
#
#
#
#
#
#
#
#
#
# d
#  6.5
#
#
#
#
#
#
#
#
#
#
#
#
# a
# da)
#
#
#
#
#
#
#
#
#
#
#
#
# pla
# Done. Average cost: 1.0541143417358398
# Starting epoch 21...
# Sampling...
#     The union board jets forged measure, have balanced the
#
#
#
#  una
#  a
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# d
# dret
#
#
#
#
# Done. Average cost: 1.0485903024673462
# Starting epoch 22...
# Sampling...
#     The Zeirelas said sale, which Iran's before stables,
# eagn
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# d
#
#
#
#
#
# j.10
#
#
# Done. Average cost: 1.0434602499008179
# Starting epoch 23...
# Sampling...
#     A'S vondow to the shipping special banker ordinary Autumation
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# .94
#
#
#
#
#
#
#
#
#
#
#
#
#
# .21
# Done. Average cost: 1.038611650466919
# Starting epoch 24...
# Sampling...
#     Over the widespread expenditure was an eight pct and wait of
#
#
#
#
#
#
#
# s
#
#
#
# ss,
#
#
#
#
#
#
#
# )
#
#
#
# )
#
#
#
#
#
#
#
# Done. Average cost: 1.0340735912322998
# Starting epoch 25...
# Sampling...
#     Morgan Sach-announced chief executive Yamy Cibyan Yilland
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# .5
# 7
#
#
#
# p)
#
#
#
#
#
#
#
#
#
#
#
# Done. Average cost: 1.0297560691833496
# Starting epoch 26...
# Sampling...
#     It said 38,000 dlrs repurchase alternate palm oil from
#
# .0
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# rea
#
#
#
# arpre
#
#
#
#
#
#
#
#
#
# Done. Average cost: 1.0257724523544312
# Starting epoch 27...
# Sampling...
#     Net, a Texai Company, Radia Corp and Mikulic in Moore to
#
#
#
#
#
#
#
#
# 4
#
#
#
# 8 67
#
#
#
#
#
# )
#
#
# s
#
#
#
#
#
#
#
#
#
#
#
#
# Done. Average cost: 1.021896481513977
# Starting epoch 28...
# Sampling...
#     The drop of work heading the came down Texaco's plant to
#
#
#
#
#
#
#
#
#
#
#
# 7
# 58
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# wh
#
#
#
#
#
#
#
# Done. Average cost: 1.018090009689331
# Starting epoch 29...
# Sampling...
#     Senior U.S. Banks have number of equity earth ICN noted
# 's
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# d
#
#
# d
# s
# 68
# 74
#
# )
#
#
# )
#
#
# Done. Average cost: 1.0144518613815308
# Starting epoch 30...
# Sampling...
#  Reuter
# .
#
#
#
#  GlE MA  684      922.4        14.5
# 46.,
#
# 8
# 8
#
#
#
#
#
#
#
#
#
#
#
#
#  1.5
#
#
#
#
#
# )
#
# )
#
#
#
#
# )
#
#
#
#
#
#
#
#
#
# Done. Average cost: 1.0110805034637451
# Starting epoch 31...
# Sampling...
#     He said the sharp gain served to disagree value, and on
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pper
#
#
#
#
#
#
#
#
#
#
# .37
#
#
#
#
#
#
#
#
#
# Done. Average cost: 1.0078202486038208
# Starting epoch 32...
# Sampling...
#     1986 net includes travelling wealthy, and about 105 mln
#
#
#  dlrs
#
#
#
#
#
# 7
#
#
#
#
#
#
#
# 6.80
#
#
#
#
#
#
#
#
#
#
#
# )
#
#
# Done. Average cost: 1.0046970844268799
# Starting epoch 33...
# Sampling...
#  Reuter
#
#  ofter sales in expects to examine the main daily
# 's
#
#
#
#
#
#
#
#
#
#
# b
# n
#
#
#
#
#
# )
# )
# )
#
#
#
# .
#
#
# )
#
#
# 4)
#
# Done. Average cost: 1.001743197441101
# Starting epoch 34...
# Sampling...
#  Reuter
#
#  Kobe
# .87
# .41         0.3
#     0.5
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# X
#
#
#
#
#
#
#
#
#
#
#
#
#
# 000
# Done. Average cost: 0.9991111755371094
# Starting epoch 35...
# Sampling...
#     Net 3,311,000 vs 798,000
#
#
#
#  domestic
#
#
#
#
#
#
#  17.9
#
#
#
#
#
# )
#
#
#
#
#
#
#
#
#
# 7
#
#
#  relauther
#
#
#
#
#
# .
#
#
#
#
#
#
#
#
#
#
# Done. Average cost: 0.9962181448936462
# Starting epoch 36...
# Sampling...
#     An EC house economist are because the Swedish Japan GAh
#
#
#
#
#
#
#
#
# -pable
#
#
#
#
#
#
#
#
#
#
#
# "
#
#
# dad
#
#
# d
#
#
#
#
# Done. Average cost: 0.9934525489807129
# Starting epoch 37...
# Sampling...
#     The spokesman quoted Robert Chority said Allie Bank had
#
#
#
#
#
#
#
#
#
#
#
#
# d
# d
# d
#
#
#
#
# d
#
# d
# d
#
#
#
#
# sstu
#
#
#
#
# Done. Average cost: 0.9912327527999878
# Starting epoch 38...
# Sampling...
#     Noranda said it hit these 100 mln dlrs in future capital
#
#
#
#
#
#
#
# ,
# 0
#
#
#
#
#
#
# s
#
# .4
#
#
#
#
#
#
#
#
#
#
#
#
# th
#
#
#
# Done. Average cost: 0.9885976314544678
# Starting epoch 39...
# Sampling...
#  Reuter
#  Marketing 73.9 mln vs 3.11 billion
#
# s
#
# 4.
# .
# 7
#
#
#  it
#
#
#
#
#
#
# upabco
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# )
#
# )
#
#
#
#
#
#
#
# Done. Average cost: 0.9860843420028687
# Starting epoch 40...
# Sampling...
#
# MS offered at preparing to enable March, which it respond
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# )
#
# ct
#
#
#
#
#
# sst,
#
#
#
# Done. Average cost: 0.9838350415229797
# Starting epoch 41...
# Sampling...
#     Replicates Industries to a Austral contribution to stop
#
#
#
#
#
#
#
#
#
#
#
# 7
# 2
#
#
#
#
#
#
#
#
#
#
#
#
#
# ,
#
# shakher
# ,
#
# Done. Average cost: 0.9816914200782776
# Starting epoch 42...
# Sampling...
#     Brokers said discovery one-antifornion potent
# s negotiated
#
#
#
#
#
#
#
#
#
#
# s
#
#
#
#
#
#
#
#
#
#
#
# )
#
#
#
#
#
#
#
#
# ,
#
#
#
#
# Done. Average cost: 0.9795472025871277
# Starting epoch 43...
# Sampling...
#  Reuter
#
#  Ricjagt Hatest SOA>
#  Hite: Workers and Kidget, Qinte
#
#
#
#
#
#
#
#
#
#
# 77
#
# 8
#
#
#
#
#
#
#
#
# "
#
#
#
#
#
#
# fate,
#
# Done. Average cost: 0.9774956107139587
# Starting epoch 44...
# Sampling...
#     NOTE: Share average its common stock was acquired on Friday
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# da
# d
#
#
#
#
#
# snadinc
#
#
#
#
# Done. Average cost: 0.9755537509918213
# Starting epoch 45...
# Sampling...
#  Reuter
#  Micro Motor Aid, which chairman Francs would be for
#  of
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ty
#
#
#
#
#
#
# dapper
#
#
#
#
#
#
#
# Done. Average cost: 0.9737050533294678
# Starting epoch 46...
# Sampling...
#     Sole traders, the spokesman Financial Leahy said.
#
#
#  Four
#
#
#
#
# 81
#
#
# 8
# 497
#
# s
#
#
#
#
# )
#
#
#
#
#
#
#
#
#
#
# 88900
# Done. Average cost: 0.9718864560127258
# Starting epoch 47...
# Sampling...
#     Revs 162.9 mln vs 133.1 mln
#
#
#
#
#
#
#  V.
# .
# p
#  bought
#
#
#
#
#
# scape
#
#
#
#
#
#
#
#
# s
#
#
#
#
#
#
#
#
#
#
#
#
#
# )
#
#
#
#
# dgene
# s
# Done. Average cost: 0.9703899025917053
# Starting epoch 48...
# Sampling...
#     Year
#  Charter Youard has gainder 1 in Monday based by a
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# -1
#
#
#
#
#
# S
#
#
#
#
#
#
#
#
#
# Done. Average cost: 0.968550443649292
# Starting epoch 49...
# Sampling...
#     No test Gulf will be in an accepting syndicate, payable South
#
#
#
#
#
#
#
#
#
#
#
#
# YV
#
#
#
#
#
# ,)
#
#
# "
#
#
#
#
#
# nn
#
# Done. Average cost: 0.9669902920722961
# Starting epoch 50...
# Sampling...
#     Net profit 57 mln vs 719,000
#  offilian
#
#
#
#  N
#
# 47,000 to
#
#
#
#
# 7
# .42
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ppatar
# Done. Average cost: 0.9653459787368774
# Starting epoch 51...
# Sampling...
#     Net 532,000 vs 570,000
#
#  dlrs
#
# 6
# 0
#
#
#  127.25
#
#
#
#
#
#
# 7 85.00
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# daggs
# er
#
#
# 4
#
#
#
#
#
#
#
# Done. Average cost: 0.9638893008232117
# Starting epoch 52...
# Sampling...
#  Start September, 1986.          1.37          nil  1,655
#   RHT.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# w
#
#
#
#
#
# s
#
#
# s
#
# 9
# Done. Average cost: 0.9623170495033264
# Starting epoch 53...
# Sampling...
#  Reuter
#
#  He said "We have about 800 Kyrangeler
#  Operating
#  House
#
#
#
#
#
#
#
#
#
#
#
# b
#
#
#
# "
#
#
#
#
# d
# ng
# fant
#
#
#
#
# Done. Average cost: 0.9608607292175293
# Starting epoch 54...
# Sampling...
#     Television funds jointly ministerial Ilacal Group Plc <SIAPL
# H
#
#
# L
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# UU.5 yet
#
#
#
#
# Done. Average cost: 0.9593727588653564
# Starting epoch 55...
# Sampling...
#  Reuter
#
#  Kraff Corp's
#
#
#
#
# 7)/89
#
# E1s
#
#
#  57
# 60 (9U16.27).
#
#
#
#
#
#
#
#
# d
#
#
#
#
#
#
#
# d
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# d
#
#
# 6.3
#
#
# Done. Average cost: 0.958031415939331
# Starting epoch 56...
# Sampling...
#     Sales 15.7 mln vs 13.8 mln
#
#
#
#  slow
#
# s
#
# 7
#
#
#
#
#  5.55
#  dlrs,
#
#
#
#
# ssare
#
#
#
#
#
#
#
#
#
#
#
#
# arse
# ,
#
#
#
#
#
#
# d
# v
# Done. Average cost: 0.9565727114677429
# Starting epoch 57...
# Sampling...
#     The vote are closed yesterday but did not say whether the
#
#
#
#
#
# d
#
#
#
#
# dmumed
# on
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Done. Average cost: 0.9551923274993896
# Starting epoch 58...
# Sampling...
#     Bange Canada has offered two billion Baut-Seprairal Telephonik
#
#
#
#
#
#
#
# 's
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# d
#
# Done. Average cost: 0.9538373947143555
# Starting epoch 59...
# Sampling...
#     Record July 1
#
#
#  gained 771 mln vs 810.5 mln
#
#
#  mln
#  Egypt
#
#
#
# ss
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# t
# Done. Average cost: 0.9525648951530457
# Starting epoch 60...
# Sampling...
#     Dun stock exchange fell with reverse each gain of 32.0
#  mln
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tis
#
#
# 6
#
#
# s
#
#
#
#
# Done. Average cost: 0.951432466506958
# Starting epoch 61...
# Sampling...
#     Net 43.5 mln vs 82.4 mln
#
#
#
#
#
#  sect
#  shares,
#
#
#
# d
# d
#
#
# st
#
#  holds
#
#
#
#
#
#
#
#
#
#
# s
#
# 82
#
# b
#
#
#
#
# stai
#
#
#
#
#
# Done. Average cost: 0.9502542614936829
# Starting epoch 62...
# Sampling...
#  Reuter
#  Eulto Suitbukon Interbank Consolidated TVX said.
#
#  Wockberk
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gia
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Done. Average cost: 0.9490821957588196
# Starting epoch 63...
# Sampling...
#     Oper shr 29 cts vs 30 cts
#
# stan
#  Republic
#
#
#
#
#
#
# )
#
#
# )
#
#  in
#
#
#
#
#
#
# 3
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# )
# 999
# Done. Average cost: 0.947982907295227
# Starting epoch 64...
# Sampling...
#     The company said it recently means it contingented an
#  on
# ,
#
#
#
#
#
#
#
#
#
#
#
# s
# D
#
#
#
#
#
#
#
#
# q
#
#
#
#
#
#
#
#
#
#
#
#
#
# Done. Average cost: 0.9469975233078003
# Starting epoch 65...
# Sampling...
#     Revs 1.98 billion vs 1.22 billion
#
# s
#
# 7
#  invest 130.2
#
#
#
#
#
#
#
#
# ss
#
#
# stral
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# '
# Done. Average cost: 0.946027398109436
# Starting epoch 66...
# Sampling...
#     The susprisacy's lower earnings program would be sold in
# press
# .
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# t
#
#
#
# Done. Average cost: 0.9450101256370544
# Starting epoch 67...
# Sampling...
#     For disaduamating and waste to certain that investors and
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# VIV.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# )
#
# Done. Average cost: 0.9441426992416382
# Starting epoch 68...
# Sampling...
#     Nine mths
#   Ol sales gain 10.00 billion vs 12.13 biloo.
#
#
#
#
#
#
#
#
#
#
#
# 8
# 0
# 7
#
#
# d
# d
#
#
# 668
#
#
# )
#
#
#
# s
#
# 7
#
# Done. Average cost: 0.9433176517486572
# Starting epoch 69...
# Sampling...
#     Revs 333.9 mln vs 306.3 mln
#
#
#
#
#  043.21 billion
#
# 3
#
#
#
#
# 0
#
#
# 7
# cts
#
#
#
# .
#
#
#
#
#
#
#
#
# s
#
# ..
#
#
#
#
#
#
# .
# s
#
#
#
# Done. Average cost: 0.9424315094947815
# Starting epoch 70...
# Sampling...
#     Northern Stap May 12 was exaged by Hebalon unsuccessful
#  Laa
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# -fdat
#
#
#
# Done. Average cost: 0.9416423439979553
# Starting epoch 71...
# Sampling...
#     Shr 24 cts vs 14 cts
#
#
#
#
#
# s
#
#
#
#
#
#
#
# 7 12.45
#
#
#
#
#
#
#  5.29
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# sy
#
#
#
#
#
#
# spl
#
#
#
#
#
#
#
# Done. Average cost: 0.9407035708427429
# Starting epoch 72...
# Sampling...
#     Millhi to a 194-16 possibly agreed with sight rallies, Northrop
#
#
#
#
#
#
# dit
#
#
#
#
#
#
#
#
#
# 68
# .88
#
#
#
#
#
#
#
#
# Done. Average cost: 0.9398623704910278
# Starting epoch 73...
# Sampling...
#     Revs 137.5 mln vs 116.2 mln
#
#
#  marks
#
#
# 9
#
# skhlil
#
#
#
# s
#
#  15,000
#
#
#
#
#
#
#
#
#
# e
# d
# '
#
#
#
#
#
#
# spect
#
#
#
#
#
#
#
#
# Done. Average cost: 0.9390566945075989
# Starting epoch 74...
# Sampling...
#  Reuter
#
#
#  Higi Save
#
# > --
#  of the balanch to emisons
#
#
#
# st
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ,
#
#
#
#
#
# tari
#
#
#
#
#
#
#
#
#
#
#
# Done. Average cost: 0.9381998181343079
# Starting epoch 75...
# Sampling...
#     Nine mths
#  company presidential previously announced
#  LPC
#
# 4
# nterma
#
#
#
# gir
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Done. Average cost: 0.9372614622116089
# Starting epoch 76...
# Sampling...
#     Reducing trading to the industries I do not drive that oppining
#
#
#
#
#
#
#
#
# s
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# wh
#
# Done. Average cost: 0.9365213513374329
# Starting epoch 77...
# Sampling...
#     The Japanese first agricultural and development of British
#
#
#
#
#
#
# sapp
#
#
#
#
#
#
# ss
#
#
#
#
#
#
#
#
#
# bbass
#
#
#
#
# Done. Average cost: 0.9356863498687744
# Starting epoch 78...
# Sampling...
#     The stock showed that it completed the debt gained in 1987
#
#
#
# s
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cflang
#
# Done. Average cost: 0.9350142478942871
# Starting epoch 79...
# Sampling...
#     American Guarantee Association of ASX shares would reduce
#
#
#
#
#
#
#
# y
# s
#
#
#
#
#
#
#
#
#
#
#
#
# by
#
#
#
#
#
#
#
#
# s
#
# g
#
# Done. Average cost: 0.934249222278595
# Starting epoch 80...
# Sampling...
#     Net 3,930,000 vs 1,805,000
#
#
#
#  ofras
#  International
#
#
#
# ss
#
#
#
#
# d
#
#
#
#
#
#
# ce
#
#
#
#
#
#
#
#
# Qprisa
#
#
#
#
#
#
#
#
#
#
# Done. Average cost: 0.9334490895271301
# Starting epoch 81...
# Sampling...
#     Shr 1.75 dlrs vs 1.48 dlrs
#
#
#
#
#
#
#
# 6
# 7
#
# s
#
# 4
#
# s
#  167.46
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# d
# new
#
#
#
#
#
# 5d
#
# 7
#
#
#
#
#
#
#
#
#  Ed
# Done. Average cost: 0.93290776014328
# Starting epoch 82...
# Sampling...
#      It rates for that extension of about 62,700 end, last Federal
#
#
#
#
#
#
# d
#
#
#
#
#
#
# dd
#
#
#
#
#
# s
#
#
#
#
# umaban
# Done. Average cost: 0.932373583316803
# Starting epoch 83...
# Sampling...
#     The conversion price pay 22.4 shares were 2,370,450 common
#
#
#
#
#
#
# 8
#
#
#
#
#
# s
#
#
#
#
# co
# s
#
#
#
#
#
#
#
#
#
#
#
#
# si
# Done. Average cost: 0.9321824312210083
# Starting epoch 84...
# Sampling...
#     The company said that Japanese banks 30 octs on Monday in
# presed
#
#  of
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ced
#
#
#
#
#
#
# ng
#
# Done. Average cost: 0.9318118691444397
# Starting epoch 85...
# Sampling...
#  Reuter
#
#  underwriters
# .50     9.30    5.60
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# m
#
# lo
# Done. Average cost: 0.931397020816803
# Starting epoch 86...
# Sampling...
#     Shr 2.87 dlrs vs 2.95 dlrs
#
#
#
#
#
#
# sts
#
#
#
#
#
# s
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# yny
#
#
#
#
#
#
#
#
# y
#
#
#  "a
# d
#
# "
#
#
# st
#
# Done. Average cost: 0.9307088255882263
# Starting epoch 87...
# Sampling...
#     Revs 3,135,126 vs 214,866
#
#
#
#
#
# p
#
# dlos
#
#
#
# 6
#
#
# )),
#
#
#
#
#
#
#
#
# p
#
# ,
#
#
#
#
# sp
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# d
#
#
#
#
# Done. Average cost: 0.9299230575561523
# Starting epoch 88...
# Sampling...
#     Net 73.8 mln vs 240.9 mln
#
#
#
#  mln
#  The
#
# A
#
#
#
#
#
#
#
#
#
#
# Nathon
#
#
#
#
#
#
#
#
# pr
# '
#
#
#
#
#
# Adling
#
#
#
#
#
#
# R
#
#
#
#
#
#
# Done. Average cost: 0.9292149543762207
# Starting epoch 89...
# Sampling...
#     Fourth Ken Agriculture project index rose 7.5 pct in Monday
#
#
#
#
#
#
# )
#
#
#
#
#
#
# d
# d
#
#
#
#
#
#
#
# ward
#
#
#
#
#
# s
#
# Done. Average cost: 0.9283535480499268
# Starting epoch 90...
# Sampling...
#     Net 2,928,527
#  vs 135,449
#
#
#
#
#
#
#
#
# X
#
#
#
#
#
#
#
#
#
#
#
#
# ss
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# )
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Done. Average cost: 0.9275810122489929
# Starting epoch 91...
# Sampling...
#     The year, Tanjug told potential writedowns, which hit Owens
#
#
#
#
#
#
#
# Ruin
#
#
#
#
#
#
#
#
#
#
#
#
#
# &g
#
#
#
#
#
#
#
#
#
#
# Done. Average cost: 0.9268117547035217
# Starting epoch 92...
# Sampling...
#     The board has swell in order to lower rates" of 4,428.
#
#
#
#
#
#
#
#
#
#
# .
# h
#
# his
#
#
#
#
#
#
# dqpene
#
#
#
#
#
#
#
#
#
# r
# Done. Average cost: 0.9260520935058594
# Starting epoch 93...
# Sampling...
#
# -1 BDPESMAT         3.28     3.72     2.06
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# d
#
# d
#
#
#
#
#
#
#
#
#
#
# dd
#
#
#
#
#
#
#
#
# Done. Average cost: 0.9253644943237305
# Starting epoch 94...
# Sampling...
#  Reuter
#
#
#  (394),
#  Vilcoco, and Ford 20 up to 50 pct
#
#
#
# s
#
#
#
# s
#
#
#
#
# 8
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# st
#
#
#
#
#
# sw
# Done. Average cost: 0.924776017665863
# Starting epoch 95...
# Sampling...
#    Net 104,139 vs 212,233
#
#
#
#
#
#
# vs in share,
#
#
#  37.2
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# )s
#
#
# )
#
#
#
# S
# )
#
#
#
# )
# )
#
#
#
# Done. Average cost: 0.9244655966758728
# Starting epoch 96...
# Sampling...
#  Reuter
#
#  Republic
#  Michael Hondas has
#
# ermed news takefment.
#
#
#
#
#
#
#
#
# d
#
#
# pp
#
#
#
#
#
#
#
#
# d
# st
#
#
#
#
#
#
#
#
# s
#
#
# Done. Average cost: 0.923936128616333
# Starting epoch 97...
# Sampling...
#     It said Dichapsic investors were not become legally in
# invest
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# s
#
# 8 27
#
#
#
#
#
# Done. Average cost: 0.9234356880187988
# Starting epoch 98...
# Sampling...
#    The truty on Monday 1970s each to offer Soviet oil fields
# ey
#
#
#
#
#
#
#
#
#
#
#
#
# 8
#
# ger
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# )
# Done. Average cost: 0.9229891896247864
# Starting epoch 99...
# Sampling...
#     Wire-Park said he expected the development in 1986 to
# 4
#
#
#
#
# sss
# s
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# d
# d
# tin
#
#
#
#
#
#
#
#
#
# Done. Average cost: 0.9226343631744385
# Starting epoch 100...
# Sampling...
#     But one market rate is very down as in advise.
#
#  Heigh
#
#
#
#
#
#
#
#
#
#
#
#
#
# Q
#
#
#
# d
# s
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Done. Average cost: 0.9222617149353027
# Starting epoch 101...
# Sampling...
#     S and P did not cautious today on Shamiret-ares.
#
#
#  farm
#
# s
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# .
#
#
#
#
#
#
#
#
# ....15
# Done. Average cost: 0.9220866560935974
# Starting epoch 102...
# Sampling...
#     Shr 1.78 dlrs vs 1.44 dlrs
#
#
#
#
#
#
#  85
# 1
# )
#
# 's
#
# ade
#
#
#
#
# drade
#
#
#
#
#
#
#
#
#
#
#
#
# nce
# ,
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# u
# p
#
#
# Done. Average cost: 0.9221688508987427
# Starting epoch 103...
# Sampling...
#     Net include an botting revenue and did nine company of 31
# .6
#
#
#
#
# TT
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# )
#
#
# r)
# )
# Done. Average cost: 0.9221047163009644
# Starting epoch 104...
# Sampling...
#     Almadia due to 46 pct of the 178 mln dlrs in cash and
#
#
#
#
#
#
#
#
#
#
#
# i
#
#
#
#
# ic
#
#
#
#
#
#
#
#
# dy
#
# -Fit
#
#
#
#
#
# 8
# Done. Average cost: 0.9222199320793152
# Starting epoch 105...
# Sampling...
#     First Financial Trust said reckeding the 945, abands
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# sccts
#
#
#
#
# o
# s
#
#
# dg
# Done. Average cost: 0.9222372770309448
# Starting epoch 106...
# Sampling...
#     "And prices are investigation of further officials tax as the
#
#
#
#
#
#
#
#
#
#
#
# d
#
# d
# d
# d
#
#
#
#
#
#
# se
#
# )
#
#
#
#
# Done. Average cost: 0.9221483469009399
# Starting epoch 107...
# Sampling...
#  Reuter
#
#  Block  5670 grad NAS-119 prices or two mln shares
#
#
#
# ssa
#
#
#
#
#
#
#
#
#
#
# tit
# iss
# and
#
#
#
#
#
#
#
#
#
#
#
#
#
# Done. Average cost: 0.9222381114959717
# Starting epoch 108...
# Sampling...
#     Net 1,001,000 vs 1,522,000
#
#
#
#  X's
#
#
# s
# -55,595
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# -A
#
#
#
# Adlap
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# b
#
# 1
#
#
# Done. Average cost: 0.9215389490127563
# Starting epoch 109...
# Sampling...
#     Net 12.9 mln vs 16.1 mln
#
#
#
#  mln
# 2A mln
#
#
#
#
#
# d
#  after the
#
#
#
#
#
#
#
#
# d
#
#
# grad
#
#
#
#
#
#
#
# bly
#
#
#
#
#
# bona
#
# Done. Average cost: 0.9212612509727478
# Starting epoch 110...
# Sampling...
#     Shr 14 cts vs 15 cts
#  prior
#  shr
#
#
#
#
# , 58.5
#
#
#
#
#
#
#  TEE
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# w
# 5
# Done. Average cost: 0.9207417368888855
# Starting epoch 111...
# Sampling...
#  Reuter
#       Avg -2-00     82.1     37.6  2.3
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# AL
# R
#
#
#
#
# to
#
#
#
#
# y,
# .
# .
# .
# .
# .
# ..
# .
# .
#
# Done. Average cost: 0.9198417663574219
# Starting epoch 112...
# Sampling...
#     Sentarial Daily said 65 basis points earlier
# s and that
#
# at
#
#
#
# sss
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# w
#
#
#
#
# Done. Average cost: 0.9192370772361755
# Starting epoch 113...
# Sampling...
#  Reuter
#
#  Use     N.V. South Korezu  3,987.50   3,966.9
#
#
#
#
#
#
#
#
#
#
#
#
#
# r
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Done. Average cost: 0.9184965491294861
# Starting epoch 114...
# Sampling...
#     Net 49.4 mln vs 34.2 mln
#
#  mank
#
# rized in
# olven
#
#
#
#
#
#
#
# g
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# c.
#
#
# ,
#
#
#
#
# s
#
#
# ss
#
# Done. Average cost: 0.9179474115371704
# Starting epoch 115...
# Sampling...
#     Under the increase to result in momentum distributions to
# h
#
#
#
#
#
#
# stippes
#
#
#
#
#
#
#
#
#
#
#
#
#
# .s
#
#
#
#
#
#
#
#
# Done. Average cost: 0.9175662398338318
# Starting epoch 116...
# Sampling...
#     He told reporters he is also after the monitoring overseas
#  hoels
# ets
#
#
# git
#
#
#
#
#
#
# 7
#
# )
#
#
#
#
#
#
# 63
#
#
# Done. Average cost: 0.9171244502067566
# Starting epoch 117...
# Sampling...
#     It said the Plaza Affairs Inc called track. The refinery
#
#
#
#
#
#
#
#
#
# m
#
# d
#
#
#
#
#
#
#
# do
# s
#
#
#
#
#
# b
# den
#
#
#
#
# Done. Average cost: 0.9169339537620544
# Starting epoch 118...
# Sampling...
#   Term director Nationale hasse market shipments must match
#
#
#
#
# gga
#
#
#
#
#
#
#
# tor
#
#
# s
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# na
# Done. Average cost: 0.916705846786499
# Starting epoch 119...
# Sampling...
#     Revs 26.7 mln vs 43.9 mln
#
# s
#
# 7
#
# 68
#
#
# 8
#
#
#
#
#
#
#
# s
#
#
# d
#
# 8
#
#
# 8
#
#
#
#
#
#
#
# s
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# d
#
#
#
#
#
#
#
#
#
#
#
#
#
# Done. Average cost: 0.9164702296257019
# Starting epoch 120...
# Sampling...
#     World balances, minimisimistics tax rights as making the
#  "a
#
#
#
#
#
#
#
# d
#
#
#
# "
#
# a
# ,
#
#
#
# , after
#
#
#
#
#
#
#
# Done. Average cost: 0.9163315892219543
# Starting epoch 121...
# Sampling...
#     Evenbyld Erigs was also ruled more difficulties and other
#
# 's
#
#
#
#
#
# strit
#
#
#
# ss
#
#
#
#
#
#
#
#
#
#
#
# "
#
# 4
# s
#
# Done. Average cost: 0.9161574244499207
# Starting epoch 122...
# Sampling...
#  Reuter
#
#
#  Johf
#  Re.J. No.
#
# -U      41.5    95.7   nil
#
#
#
#
#
#
#
# .
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  IK
# T
#
# .T.
#
# .....
#
#
#
# ..
# Done. Average cost: 0.9159936904907227
# Starting epoch 123...
# Sampling...
#     Net alnosuffaed results in the February Logis in 1987.
# i
#
#
#
#
#
# dha
#
#
#
#
#
#
#
# dd
#
#
# dmart
#
#
#
# sy
#
#
#
#
#
#
# o
# Done. Average cost: 0.9160643219947815
# Starting epoch 124...
# Sampling...
#     CORN 174.2 mossol said in the new banking charges as a
# dested
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# du
#
#
#
#
#
# 8 consoliban
# Done. Average cost: 0.9161040782928467
# Starting epoch 125...
# Sampling...
#     Borg-Warner last waht total 566.5 mln marks shipment.
#
#
#
#
#
#
#
#
# der
#
#
#
#
#
# mpire
#
#
#
#
#
#
#
# d
# st
#
#
#
#
#
# s
#
#
# Done. Average cost: 0.9160863757133484
# Starting epoch 126...
# Sampling...
#     Sales for two years in the first half their market 20
#
#
#
#
# s
#
# ss
#
#
# tem
#
#
#
#
#
# dous
#
#
#
# d
#
#
#
#
#
# d
# ddv
#
#
# Done. Average cost: 0.9162408709526062
# Starting epoch 127...
# Sampling...
#     Nine mths
#
#
#  Dome said it filed with the Securities and
#
#
#
#
#
#
#
#
#
#
#
# d
# d
# s
#
#
#
#
#
#
#
# dst
#
#
#
#
# s
#
#
#
#
#
#
#
#
# Done. Average cost: 0.9169163703918457
# Starting epoch 128...
# Sampling...
#     Oper shr 49 cts vs 15 cts
#  oth
#
#
#  sorr
# .
#
#
#
#
#  in
# overt
#
#
#
#
#
#
# ts
#
#
#
#
# ss
# are
#
#
#
#
#
#
# stre
#
#
#
#
#
#
# ss
#
#
#
# Done. Average cost: 0.9171501994132996
# Starting epoch 129...
# Sampling...
#     "Alganisunce, the market from the Yedman's balance during
# um
#
#
#
#
# dent
#
#
#
#
#
# gax
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Done. Average cost: 0.916054368019104
# Starting epoch 130...
# Sampling...
#     NOTE: 1986 net includes restricted the rated for extraordinary
#
#
#
#
#
#
#
#
#
# d
# ner
#
#
#
#
# er
#
#
#
#
#
#
#
#
#
#
#
# 1
# Done. Average cost: 0.9151053428649902
# Starting epoch 131...
# Sampling...
#  Reuter
#
#  "Boug Class B warned Safegustath Authority told reporters
#
#
#
# .
#
#
#
#
#
#
#
#
#
#
#
# g
#
#
# 8
#
#
# 4
# mm
# n
#
#
#
# Done. Average cost: 0.9144039750099182
# Starting epoch 132...
# Sampling...
#     Nine mths
#
#  472.5 mln vs 625.5 mln
#
#
#
#
#
# 7
# I
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# IHH
#
#
#
#
#
#
#
# W
# WWL
#
#
#
#
#
# u
#
# U"
# "
# Done. Average cost: 0.9138395190238953
# Starting epoch 133...
# Sampling...
#     Net 3,257,000 vs 2,452,000
#
#
#
#
#
# A
#
# d
#
#
#
#  277
#
#
#
#
#
#
#
#
#
# LIL
#
#
#
#
#
#
#
# e
# ,
#
#
# Y
# a
# ,
#
#
# T
#
#
#
#
# L
#
# As
#
#
#
#
#
#
#
# Done. Average cost: 0.9130368828773499
# Starting epoch 134...
# Sampling...
#     Revs 306,946 vs 106,846
#
#
#
#
#
#
# X
#
#
# ,
# ,600,000
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# k
# Q
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 89826
#
#
# 8
#
#
#
#
#
#
#
#
#
# Done. Average cost: 0.9121342897415161
# Starting epoch 135...
# Sampling...
#     Seligtanics, such as part of its own position on the real
#
#
#
#
#
#
# d
# moty
#
#
#
#
#
# yyy
# ,
#
#
#
# h,
#
#
#
#
#
#
#
# "
#
# Done. Average cost: 0.9114058017730713
# Starting epoch 136...
# Sampling...
#  Reuter
#
#
#  Yell All Corp
#  <BPMIL............................17................160
#
#
#
#
#
#
#
# .....F......
# Done. Average cost: 0.9112052917480469
# Starting epoch 137...
# Sampling...
#     Keels said a spokeswoman for the United States was 0.4763
#
#
#
# "
#
# d
#
#
# zzud
#
#
# ,
#
#
#
# ,
#
#
# gemant
#
#
#
#
#
#
#
# Done. Average cost: 0.910347580909729
# Starting epoch 138...
# Sampling...
#  Reuter
#  Hourcel experts under U.S.
#  Phillips Financial
#
#
#
#
#
#
#
#
#
#
# d
# d
#
#
#
#
#
#
#
# "
#
#
#
# --sched
#
#
#
#
#
#
#
#
#
#
# )
# Done. Average cost: 0.9097579121589661
# Starting epoch 139...
# Sampling...
#     "They are about 17 pct on a serious call" to unaudi volumes
#
#
#
#
#
#
#
# sota
#
#
#
# g
#
# s
#
#
# m
# s,
#
# ace
# b
#
#
#
#
# Done. Average cost: 0.9093148708343506
# Starting epoch 140...
# Sampling...
#     Using tax cuts for the week was noted.
# ..10.50 dlrs a share
#
# ated
#
#
#
#
#
# s
#
#
# st
#
#
#
#
#
#
#
#
#  of
#
#
#
#
#
#
#
#
# Done. Average cost: 0.9089401364326477
# Starting epoch 141...
# Sampling...
#  Reuter
#
#
#  WH
#  3"
#         3.70         0.61
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ))
#
#
#
# ))
#
# -7,),
# Done. Average cost: 0.908897340297699
# Starting epoch 142...
# Sampling...
#  Reuter
#
#
#  John Runne I-L>.
#    Nilbart Loka said. Average
#
#
#
#
#
#
#
#
#
#
#
# G
#
#
#
#
#
#
# S
# S
#
#
#
#
#
#
#
#
#
#
# QP
#
# A
#
#
#
# A
# Done. Average cost: 0.9082167148590088
# Starting epoch 143...
# Sampling...
#     Nine mths
#  shareholder loans against last month's discount
#
#
#
#
#
#
#
#
#
#
#
# s
# in
#
#
#
#
#
#
# s
#
#
#
# d
# sa
#
#
#
#
#
#
#
# Done. Average cost: 0.9079869985580444
# Starting epoch 144...
# Sampling...
#     Note: Full name Monday's Datagammed Shimbuer International
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# dad
#
#
#
#
#
#
#
#
# rid
#
# Done. Average cost: 0.9078807234764099
# Starting epoch 145...
# Sampling...
#     Net 199,019 vs 79,420
#
#
#
#
#
# ddlost
#
#
# 3
# ,
#
# "6
#
#
# )
# )
# )
#
# 1
# 8
# 1
#
# 7
# )
#
#
#
# 65
#
#
#
#
#
#
#
# 00
#
#
#
#
#
#
#
# 7
#
#
#
#
#
# t
#
#
# Done. Average cost: 0.9079204201698303
# Starting epoch 146...
# Sampling...
#  REUTER
# DDDI  MATRU HAROR
#      LAITW VS Aun
#
# RSINUM
#
#
#
#
#
#
#
#
# 'Q
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# o-
#
# Done. Average cost: 0.9080707430839539
# Starting epoch 147...
# Sampling...
#     Vice New Zealand students said Basil shares in the
#  put
#
#
#
#
#
#
#
# ed
#
# sy
#
#
#
#
#
# d
# d
# ssdy
#
#
#
#
#
#
#
#
# Qup
#
#
# Done. Average cost: 0.9079048037528992
# Starting epoch 148...
# Sampling...
#     Nine mths
#
#  series of comparisons with Yankin Giarnies, diplomats
#
#
#
#
#
#
#
#
#
#
#
#
#
# d
# dmay
# a
#
#
#
#
#
#
#
# "
#
# Done. Average cost: 0.907717764377594
# Starting epoch 149...
# Sampling...
#  Export-    51.0  5.4 mln    68.90  vs  38.8
#
#
#
#
# (
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# d
#
#
# ^0
#
# )
#
#
# bdy
#
#
# )
#
# )
#
# Done. Average cost: 0.9078933596611023
# Starting epoch 150...
# Sampling...
#     Revs 9,009,000 vs 7,850,000
#
#
#
# , lound
#  and
#
#
#
#
#
# d
#
#
#
#
# sa)
#
#
#
# dror
# )
#
#
#
#
#
#
#
#
#
#
# p
#
# st
#
#
#
#
#
#
#
#
#
# s
#
#
# Done. Average cost: 0.9078475832939148
# Starting epoch 151...
# Sampling...
#     Revs 33.9 mln vs 32.5 mln
#
#
# B
#
# L
#
# I
#
#
#
#
#  Myplan
#
#
#
# 15
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# .
# 0
#
#
#
#
#
# Done. Average cost: 0.9080341458320618
# Starting epoch 152...
# Sampling...
#     Net 1,719,370 vs 723,060
#
#
#
#
#
#
#
#
# lp destrolly
#
#
#
#
#
#
#
# nay
#
#
#
#
#
#
#
# ni
# ncina
#
#
#
#
#
#
# drax
#
#
#
#
#
#
#
#
#
#
#
#
# i
# Done. Average cost: 0.9078516364097595
# Starting epoch 153...
# Sampling...
#     Het presidents were strike ahead on closings.
# " Bermann
#  an
#
#
#
#
#
# rise
#
# at
#
#
#
#
#
# s
#
#
#
#
#
#
#
# n
#
#
# s,
#
# s
# Done. Average cost: 0.9079425930976868
# Starting epoch 154...
# Sampling...
#     When Guyardaus has so far has interest rate retailer, the
#
#
#
#
#
#
#
#
#
#
#
#
#
# g
# ad
#
#
#
#
#
# d
#
#
# dad
#
#
#
# s
#
# d
#
# Done. Average cost: 0.9083094596862793
# Starting epoch 155...
# Sampling...
#     But to lend 25,000 tonnes found to a series of finally in
# where.
#
#
# ged
#
#
#  41
#
#
#
#
# ri.
#
#
#
# .,
# .
# .
#
#
#
# Done. Average cost: 0.9086893200874329
# Starting epoch 156...
# Sampling...
#     Liedel arbitrates shareholders and me about the company's
#
#
#
#
#
# dgant
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# y
#
# sch
# a
#
#
# Done. Average cost: 0.9086642861366272
# Starting epoch 157...
# Sampling...
#     Asked by a his USA and shareholders at a substantial bound
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# d
#
#
#
# dd
#
#
# d
# d
#
#
#
# mm
#
#
#
# s
# Done. Average cost: 0.9090267419815063
# Starting epoch 158...
# Sampling...
#     Consumins although the guarantee Ariane will also allow
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# t
# ,
#
# yen
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ,
#
# Done. Average cost: 0.9091836214065552
# Starting epoch 159...
# Sampling...
#     "They would make bars it is strong earnings trading, and
#
#
#
#
#
# b
#
#
#
#
#
#
#
# are
# ,
#
#
#
#
#
#
# s
#
#
#
#
#
#
#
#
#
#
#
#
# Done. Average cost: 0.909229576587677
# Starting epoch 160...
# Sampling...
#     Net 215 mln vs 165 mln
#
#  market
#  basio over
# uraichi is
#
# ord
#
#
#
#
#
# d
#
#
#
#
#
#
#
#
#
#
#
#
# S
#
# d
# y,
#
#
#
#
# d
# ds
#
#
# Done. Average cost: 0.9095906615257263
# Starting epoch 161...
# Sampling...
#     Nine mths
#  public offering will not total a
#  on-cilients
# er
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 3
#
#
# 8
#
#
#
#
#
#
#
#
#
# Done. Average cost: 0.9099480509757996
# Starting epoch 162...
# Sampling...
#     Spain on its votes for the seven yards on 91 pct of the
#
#
#
#
#
#
#
#
#
#
#
#
#
# rig
# a
#
#
#
# s
#
#
#
#
#
#
# a
# t
#
#
#
#
# qu
#
# Done. Average cost: 0.9097043871879578
# Starting epoch 163...
# Sampling...
#     Leslieft-Portugueter ninetborge Bank of Seven metboding
#
# er
#
#
#
#
#
#
#
#
#
#
#
#
# dct
#
#
#
#
#
#
#
#  said
# a
#
#
# d
# d
#
# Done. Average cost: 0.9094128608703613
# Starting epoch 164...
# Sampling...
#     By the global backerhaem had been joy of the quotas - imprising
#
#
#
#
#
#
#
#
#
#
#
# naper
#
# )
#
#
#
#
#
#
#
#
#
# na
#
#
# Done. Average cost: 0.9091072082519531
# Starting epoch 165...
# Sampling...
#  Reuter
#
#
# decomple Walt Yugoslution
#
#  Agency.
#
# ctralle
# s
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ,
#
#
#
# 68.25
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# )
# b
#
# Done. Average cost: 0.9086624979972839
# Starting epoch 166...
# Sampling...
#     NOTE: Share adjusted for 3-methy to asset acquisition.
#
#
# dater
#
#
#
#
#
#
#
#
#
#
# d
# icad
# 's
#
#
#
#
# k
# .
#
#
#
#
#
# p
# Done. Average cost: 0.9079898595809937
# Starting epoch 167...
# Sampling...
#     Revs 632,988 vs 484,788
#
#
#
#  dlr
#
#
#
#
#
#
#
# sag
#
#
#
# pmants
#
#
# gin
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# n
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Done. Average cost: 0.907616376876831
# Starting epoch 168...
# Sampling...
#     Other criticized its posted post third quarter previously in
# unit
#
#
#
#
#
#
# 6
#
#
#
#
#
#
#
#
#
#
#
# .
#
#
#
#
#
#
#
#
#
#
#
# Done. Average cost: 0.9070850014686584
# Starting epoch 169...
# Sampling...
#     Speaking : into an inventured at 56, Federal Loan Assemata
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# dp
#
#
# dtd,
#
#
#
#
#
#
#
# d
# d
# 5
#
#
# Done. Average cost: 0.9064643979072571
# Starting epoch 170...
# Sampling...
#  Reuter
#
#  IB (130-)) Linesevill, a California base of
# er
#
#
#
#
#
#
# s
# s
#
#
#
# s
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# "
#
#
#
#
#
#
#
#
#
#
#
#
#
# Done. Average cost: 0.905792236328125
# Starting epoch 171...
# Sampling...
#     Unimons said he would be sustained in one or full-speed
#
#
#
#
#
#
#
#
#
# Ham
#
#
#
#
#
#
#
#
#
#
# "
#
#
#
#
#
#
# r
#
# d
# t
#
#
#
#
# Done. Average cost: 0.905684232711792
# Starting epoch 172...
# Sampling...
#     Most announced it, during the same period to 366
#  in the
#
#
#
#
#
#
#
#
# dray
# 's
#
#
#
#
#
# R
#
#
#
# ,
#
#
#
#
#
#
# ,
#
# V
#
#
# Done. Average cost: 0.9049321413040161
# Starting epoch 173...
# Sampling...
#     Dole said new package rating after Japan implements the
#
#
#
#
#
#
#
#
#
# dre
# t
#
#
#
#
#
#
# g
#
#
#
# g
#
#
#
# m
#
# struple
# Done. Average cost: 0.9045082330703735
# Starting epoch 174...
# Sampling...
#     Shr loss 42 cts vs loss one ct vs profit 12.
#
#  le
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# due
#
#
#
#
#
#
#
#
#
#
#
# "d
#
# 7
#
# t
#
#
#
#
#
#
#
#
# Done. Average cost: 0.9043312072753906
# Starting epoch 175...
# Sampling...
#     Net 129,846 vs 49,148
#
#
#
#
#
#
#
# in
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# dd
# Ld
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ss
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Done. Average cost: 0.9040963649749756
# Starting epoch 176...
# Sampling...
#     Net 608,000 vs 643,000
#
#
#  Ind
# es
#
#
#
#
#
# ss
# nas
# ex
#
#
# d
#
#
# s
#  eurint
#
#
# g
#
#
# 6
#
#
#
#
#
#
# 8
#
#
#
#
#
#
#
#
#
#
# R"
#
#
#
#
#
# Done. Average cost: 0.9040914177894592
# Starting epoch 177...
# Sampling...
#  Reuter
#
#  Bock   1860  169,600     851.19  31.84
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Done. Average cost: 0.905450165271759
# Starting epoch 178...
# Sampling...
#     In four-year credit Board, said it signed a little placement,
#
# Ac
#
#
#
#
#
# d
#
#
#
#
#
#
#
#
#
#  ad
#
#
# spe
# d
#
#
#
#
# Done. Average cost: 0.9040306210517883
# Starting epoch 179...
# Sampling...
#  REUTER
# INT
#
# )
# Adi-100    183.20  152.2.
#
#  28.54 b
#
#
#
#
#
#
#
#
# .96
#
#
# )
#
#
# )
#
# 6
#
#
#
#
#
#
#
#
# y
#
#
#
#
#
#
#
#
#
#
# rla
#
#
#
#
# Done. Average cost: 0.9035170674324036
# Starting epoch 180...
# Sampling...
#     The repurchase between June 17, King into a publiving of
# er
#
#
#
#
#
# d
#
# st
#
# ))
# ,
#
#
#
#
#
#
#
# usis
# and
#
# ary
# Done. Average cost: 0.9031344652175903
# Starting epoch 181...
# Sampling...
#     Sales of the company's RDP 1987 was
# eagreement again might
#
#
#
#
#
# ss
#
#
#
#
#
#
# "
#
#
#
# d
# nord
#
#
#
# ss
#
# dy
#
#
#
# Done. Average cost: 0.9026517271995544
# Starting epoch 182...
# Sampling...
#     "In histon, if defending the options in Kuwait want is it
#
#
#
# eted
#
#
#
#
#
#
#
# d
# cord
#
#
#
#
#
#
#
#
# sm
# d
#
#
#
#
#
# Done. Average cost: 0.9028294086456299
# Starting epoch 183...
# Sampling...
#     Shr 84 cts vs 87 cts
#
#
# cgorring
#
#
# bir
#
# nability
#
#
# ss
# st
#
#
#
#
#
#
#
#
# "
#
#
#
# s
#
#
#
# d
#
#
#
# st
#
#
#
#
# g
#
#
#
#
#
#
#
#
#
#
# Done. Average cost: 0.9027848243713379
# Starting epoch 184...
# Sampling...
#     Acknomne-Iran formed without haddres and continuation
# ,
#
# Ha
# s
#
#
#
#
#
#
#
#
#
#
#
# d
# ar
#
#
#
#
#
#
#
#
# Tri,
#
#
#
#
# St
# Done. Average cost: 0.9021478891372681
# Starting epoch 185...
# Sampling...
#     Shr 1.97 dlrs vs 1.25 dlrs
#
#
#
#
#
# s
# dent
#
#
#
#
#
# s
#
#  state
#
#
#
#
#
# s
# day
#
#
#
#
#
#
#
# d
#
# ss
# strain
#
#
# n
#
#
#
#
#
#
#
#
#
# Done. Average cost: 0.9020097255706787
# Starting epoch 186...
# Sampling...
#     Net 2,650,000 vs 1,481,000
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# .
# is
#
#
#
#
#
#
#
#
#
#
#
#
# t
#
#
#
# s
#
#
#
#
#
#
#
#
#
#
#
# w
#
#
#
# d
#
#
# d
# X
#
#
#
#
#
#
# Done. Average cost: 0.90196293592453
# Starting epoch 187...
# Sampling...
#     Redstonable calls, which were frozen through joint
#  nearly
#
#
#
# gota
#
#
#
#
#
#
#
#
# w
#
# wi
#
#
#
#
#
#
# dting
#
# unt
# Done. Average cost: 0.9021651148796082
# Starting epoch 188...
# Sampling...
#     Net 1,649,000 vs 4,115,000
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 706
#
#
# "
#
#
# 0))
#
#
#
#
# ds
#
#
#
#
#
#
#
#
#
#
# )
#
# d
#
#
#
#
#
#
# dorn
#
#
#
#
# s
# )
#
#
# Done. Average cost: 0.902442991733551
# Starting epoch 189...
# Sampling...
#     NOTE: 1987 1st a profit filed in the quarter, ending 5260
#
#
#
#
#
#
#
#
#
# Co
#
# s
#
#
#
# tron
#
#
#
#
#
#
# ,
# .
#
#
#
#
#
#
#
# Done. Average cost: 0.9020413160324097
# Starting epoch 190...
# Sampling...
#     Nine Months
#
#  declined commitment for dlrs.
# 7 private
#
#
#
#
# plt
#
#
#
#
#
# ss
#
#
# detty
#
#
#
#
#
#
#
# clam
#
#
#
#
# gt
#
# Done. Average cost: 0.9024228453636169
# Starting epoch 191...
# Sampling...
#     S and P cited a 20 pct interest in the remaining quota.
#
#
#
#
# p Kodak
#
#
#
#
#
#
#
#
#
#
#
# d
# r
#
#
#
# s
#
# p
#
# s
#
#
# 6
# Done. Average cost: 0.9023817777633667
# Starting epoch 192...
# Sampling...
#     The Community would not attracile half out of what trading
# stor
# s
#
#
#
# m
# st
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# s
#
# stan
# Done. Average cost: 0.902408242225647
# Starting epoch 193...
# Sampling...
#     BILMBO in reported excess output from one-way, called IBM
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# T
# j
#
#
#
#
# Done. Average cost: 0.9025676846504211
# Starting epoch 194...
# Sampling...
#     Net 5,882,000 vs 4,449,000
#
#
#
#
#
# nised
#
# ,
#
#
#
#
#
# sdd of
#  by
#
#
#
#
#
# ry
#
#
#
#
#
# sis
#
#
#
# day
#
#
#
# dy
#
#
#
#
#
#
#
# dro
# Done. Average cost: 0.9024279713630676
# Starting epoch 195...
# Sampling...
#     Moody's circury impact on the gold price increased 706 mln
#
#
#
#
#
#
# d
#
# 6
#
#
#
#
#
#
#
#
#
#
# X
#
#
#
#
#
#
#
# )
#
#
#
#
#
#
#
# Done. Average cost: 0.9028683304786682
# Starting epoch 196...
# Sampling...
#     Revs 56.1 mln vs 52.6 mln
#
#  Av
#
#
#
# 6d097 gurning,
#
# Jad
#
#
# gera
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# .......
# 5
#
#
#
#
#
#
# Done. Average cost: 0.9029977917671204
# Starting epoch 197...
# Sampling...
#  Reuter
#
#  Bord T SAMBANCONI.
# .     OP 1, 1943.
# 0 RGK
#
# INT --
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# D
#
#
# R
#
#
#
#
#
#
#
#
#
# Q
# Done. Average cost: 0.9078015089035034
# Starting epoch 198...
# Sampling...
#     The minority dollar six monthly still begon for the first
#
#
#
#
# s
# s
#
#
#
#
#
# stas
#
#
#
#
#
#
#
#
#
#
#
# stied
#
#
# d
#
# Done. Average cost: 0.9063286185264587
# Starting epoch 199...
# Sampling...
#  Reuter
#
#  Alin Plc>. Ongles said
#
# .16 pct marged
#  in
#
#
#
#
#
#
#
#
#
# i
#
#
#
#
#
#
#
#
#
#
#
#
#
# f
# n
#
#
#
#
#
#
#
#
# U
# k
#
#
#
#
#
#
#
#
# Done. Average cost: 0.903107225894928

# %% [markdown]
# Вроде выводится какой-то нормальный текст, но очень много переводов строки, из-за того, что в обучающих текстах их много.
# Пытаться избавиться от этого можно конкатенируя каждую новость через пробел, но тогда будут очень длинные строки инпута.

# %%
hidden_size = 200
num_layers = 3
batch_size = 500
num_epochs = 80

# %% [markdown]
# Теперь потренируем модель со своим GRU.

# %%
model = RnnLm(hidden_size=hidden_size, num_layers=num_layers, batch_size=batch_size, num_epochs=num_epochs,
              num_tokens=100, charlevel=True, cell_type="gru")
model.train("reuters_parsed.txt")
# Out:
# Starting epoch 0...
# Sampling...
#  Bruzwill be rate of the its California countryet ships
#  to
#
#
#
#
#
#
#
#
#
#
#
# alk
#
#
#
#
# I
#
#
#
#
#
#
#
#
#
#
#
#
# Yit has
# Done. Average cost: 1.6597518920898438
# Starting epoch 1...
# Sampling...
#  Reuter
#
# be sood apparent to affected
#  further
#
#
#
#
#
#
#
# ge
#
#
#
#
#
#
# elve
#
#
#
#
#
#
#
#  Putum
#
#
#
#
#
#
#
#
# -I computer
# Done. Average cost: 1.2289400100708008
# Starting epoch 2...
# Sampling...
#     Revs 345,000 vs 7,200,000
#
#
#
#
#
#
#
#
#
#
# le
#
#
#
#
#
#
#
#
#
#
#
# ha,
#
# hal
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Done. Average cost: 1.1550521850585938
# Starting epoch 3...
# Sampling...
#     "I'm value a 56 pct be about 280 billion gain of 40 pct
#
# yehtly
#
#
#
#
#
#
#
#
#
#
#
# wo
#
# earn
#
#
#
#
#
#
# hew
#  "i
# Done. Average cost: 1.1150093078613281
# Starting epoch 4...
# Sampling...
#     The spokesman said this had a coffee speculation at a crow by
#
#
#
#
# s
#
#
# well
#
# t
#
# est
# .
#
#
#
# -based
#
#
#
# Done. Average cost: 1.088284969329834
# Starting epoch 5...
# Sampling...
#     Nine Mths
# 17
#      LDOR
#    World Inc said its ability
#
#
#
#
# utio
#
#
#
#
#
#
#
#
# fall,
#
#
#
#
#
#  Taukmant,
#
# has
#
# Done. Average cost: 1.068479061126709
# Starting epoch 6...
# Sampling...
#  REUTER
#     Revs 445.8 mln
#
#
#  912,000
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# he
#
#
#
#
#
#
# is
#
#
#
#
#
#
#
#
#
#
#
#
#
# ope.
#
#
#
# ton
# .
#
#
#
#
#
#
#
# h
# Done. Average cost: 1.0529919862747192
# Starting epoch 7...
# Sampling...
#     It said in hintwhich long-term its fuel prices rated 315,000
#
#
#
#
#
#
# s
#
#
# ke,
#
# he
#
#
#
#
#
#
#
#
#
# Joweu
#
# ,
# Done. Average cost: 1.040473222732544
# Starting epoch 8...
# Sampling...
#     NOTE: Cattle chairman Affree Trump exports modifications would
#
# the
#
#
#
#
# Latin
#
#
#
#
# I
#
#
#
#
# have
#
#
#
#
#
# Done. Average cost: 1.0299445390701294
# Starting epoch 9...
# Sampling...
#     Non-certaoning by Nigeria's Democrat shares not and a
# nuation
#
#
#
#
#
# I
#
#
#
# Li
#
# "
#
# an
#
# ,
#
#
# have
#
#
#
# pl
# Done. Average cost: 1.0210435390472412
# Starting epoch 10...
# Sampling...
#     Makote Bill said he would achieve its AIMS activity system
#
# on
# .
#
#
#
# Li
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# a
#
# oi
#
#
#
#
#
#
# Done. Average cost: 1.0135241746902466
# Starting epoch 11...
# Sampling...
#     Sales 102.6 mln vs 771.3 mln
#
#
#
#
#
#
#
#
#
#
#
#
#
# o
#
#
#
#
#
#
#
#
#
#
# <
#
#
# >
# .
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# W
#
#
# ,
#
# ks,
#
# hall
#
# Done. Average cost: 1.0067869424819946
# Starting epoch 12...
# Sampling...
#     The oilseed earnings equal to the planned statement on Tuesday
#
# it
#
# ong
#
#
# ouk
#
#
#
#
#
#
#
#
#
#
#
#
#
# .
#
#
#
#
#
# Done. Average cost: 1.0007718801498413
# Starting epoch 13...
# Sampling...
#     BAISI said ObBE officials have seen cuttingly got herd about
#
#
#
#
# at
#
#
#
#
# ution
#
#
#
#
#
#
# ate
#  said.
#
#
#
# Done. Average cost: 0.9954923987388611
# Starting epoch 14...
# Sampling...
#     A spokesman said the employee politicians for most-roubled
#
#
#
#
#
#
#
#
#
#
#
#
# i
#
#
#
# o
#
#
#
#
#
# op
#
#
#
# a
#
# in
#
# e
# Done. Average cost: 0.9908132553100586
# Starting epoch 15...
# Sampling...
#  Reuter
#
#
# a gain figures on details and said the
#
#
#
#
# has
#  won
#
#
#
#
# ser,
#
# had
#
#
#
# was
#
#
# and,
#
# has
#
#
#
#
# th
# Done. Average cost: 0.986622154712677
# Starting epoch 16...
# Sampling...
#  Reuter
#
#       04 cts vs 15 cts
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Y
#
#
#
#
#
# wo
#
# ,
#
# GE
#
#
# apa
#
#
#
#  the
#
#
#
#  as
#
#
#
#
# ap
#
#
# on
# Done. Average cost: 0.9830824732780457
# Starting epoch 17...
# Sampling...
#     Vichon Kank Director of White Territoro, Wall Staff and AT
#
# His
#
# me
# tive
#
#
#
#
# have
#
#
#
# ;
#
# have
# ,
#
#
#
# Done. Average cost: 0.979591429233551
# Starting epoch 18...
# Sampling...
#     A spokesman for the Economic Subsidiary Siregloson said his
#
#
# here
#
#
#
#
# pore
#
#
#
#
# ,
#
# he
#
#
#
#
# 's
#
#
# an
# Done. Average cost: 0.976302981376648
# Starting epoch 19...
# Sampling...
#     However, the division will have to be necessary average by
#
#
#
#
# ore
#
#
# s-
#
#
#
#
# go
#
#
# ented.
#
#
#
#
#
#
#
#
# e
# Done. Average cost: 0.9733636975288391
# Starting epoch 20...
# Sampling...
#  Reuter
#
#
#     Nine mths
#
# 4  98.63   0.36       0.7
#  040
#
#
#
#
#
#
#
#
#
# 4
#
#
#
#
#
#
#
#
#
#
#
# >
#
# , a privately
#
# enk
#
#
# Done. Average cost: 0.9707134366035461
# Starting epoch 21...
# Sampling...
#  REUTER
#
#
# IL7 SINTINNTU
# S
#
#   LTLG
#  said the
#
#
#
#
#
#
# had
#
#
#
# plo
# ed
#
#
#
# s-400,
#
# he
#
#
#
# half
#
#
#
#
#
#
#
# o
#
# ,
#
#
# Done. Average cost: 0.9682920575141907
# Starting epoch 22...
# Sampling...
#  Reuter
#
#
# ; Shor Industries <PLL> for Toronto.
#
#
#
# power
#
#
#
#
#
#
#
# I.,
# .
# >.
#
#
#
#
#
# ity
#
# on
#  of
#
#
# s
#
# ite
#
#
#
#
# Done. Average cost: 0.9660831689834595
# Starting epoch 23...
# Sampling...
#     Use found, House Finance (NNP) was for the co-lines
#  that
#
#
#
# enger
#
# oos
#
# u
#
#
#
# es
#
#
# a
#
# le
#
#
#
# haft
#
# Done. Average cost: 0.964104950428009
# Starting epoch 24...
# Sampling...
#     Nine mths
#  value figure, which will outsorn western
#
#
#
# has
#
#
# ts
#
# at
#
#
# tan
#
#
#
#
#
# ,
#
#
#
#
#
#
#
#
# an
#
#
#
#
#
#
# Done. Average cost: 0.962226927280426
# Starting epoch 25...
# Sampling...
#  Reuter
#
#
#      Nine mths
#
# halme its half of Weathernhold last
#
#
# have
#
#
# th
#
#
#
#
#
#
#
#
#
# o
#
#
# holders.
# ....
#
# Done. Average cost: 0.9606695771217346
# Starting epoch 26...
# Sampling...
#     Nine mths
#  vs 74 dlrs a barrel, from its NB-1
#  accord
#
#
# ul
#
#
#
#
#
# op
#
# enfiling
#
#
# es
#
# inity
# 's
#
#
# he
#
# Done. Average cost: 0.959236741065979
# Starting epoch 27...
# Sampling...
#
# in volume was ruled in his slective agencies.
#  "Buy
# is
#
# hang
# .
#
#
#
#
#
#
#
# enders
#
#
# hospe
#
#
#
#
#
# ate
# ,
#
#
# Done. Average cost: 0.9577538371086121
# Starting epoch 28...
# Sampling...
#     Masonma but will be delivered on Monday from September to
#
#
# ate
#
#
#
#
#
# ate
#
#
# ends.
#
#
#
#
#
#
#
# ated
#
#
#
#
#
# Done. Average cost: 0.9563865661621094
# Starting epoch 29...
# Sampling...
#     On June 19 betiming shares would be
# ts a diluted money
#
# in
#
#
#
#
#
# out.
#
#
#
#
#
#
#
#
#
#
#
#
# his
#
#
# whey
#
#
#
# ha
# Done. Average cost: 0.9551019072532654
# Starting epoch 30...
# Sampling...
#     Miller's traded as part of the economic offer for transfers
#
#
# ty
# ete
# .
#
#
#
#
#
#
#
#
#
# who
#
#
# we
# hen
#
#
#
#
#
# Done. Average cost: 0.9537123441696167
# Starting epoch 31...
# Sampling...
#     NOTE: Full numels from 476 mln dlrs in 1986 as a result of
#
#
# ees
# .
#
#
#
#
#
#
#
#
#
#
#
#
# well
#
#
# phle
#
# many
#
# Done. Average cost: 0.9524462819099426
# Starting epoch 32...
# Sampling...
#     Belgium head purchases are over his class A stock and
#  a
#
# uti
# v
#
# ent
#
#
#
#
#
#
# an
#
#
#
#
#
#
#
# an
#  on
#
#
#
#
#
#
# Done. Average cost: 0.9513599276542664
# Starting epoch 33...
# Sampling...
#     Avg Shr 58 mln vs 86.2 mln
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ^>,
#
#
#
#
# WX>
#
# and
#
#
#
#
#
#
#
#
#
#
#
#
#
# ,,
# ham
#
# wa
#
#
# will
#
#
#
#
#
# Done. Average cost: 0.9503705501556396
# Starting epoch 34...
# Sampling...
#     Net 34.2 mln vs 36.1 mln
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Ho>
#
#
# gs
#
# ties
#
# ep
# ed
#
#
#
#
#
#
#
# he,
#
#
#
# ,
# .,
#
#
#
#
#
#
#
#
#
# Done. Average cost: 0.9494854807853699
# Starting epoch 35...
# Sampling...
#     Avg shrs 334,000 vs 790,000
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# >
#
#
# G
#
#
#
# zecher
#
#
# es
# all
#
#
#
# palk
# Done. Average cost: 0.9487197995185852
# Starting epoch 36...
# Sampling...
#     Bally Debt presistes anythe application at 125.50 mln and
#
#
#
#
#
#
#
#
#
#
#
# hos
#
#
#
# sele
#
# .
#
#
#
#
#
#
# ann
# pol
# Done. Average cost: 0.9480103850364685
# Starting epoch 37...
# Sampling...
#     Net 15.0 mln vs 11.0
#  mln
#
#
#
#
#
#
#       177.4
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# s>
# ,
#
#
#
#
#
#
#
#
# g
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Done. Average cost: 0.9473878741264343
# Starting epoch 38...
# Sampling...
#     But Guller and the SNCO is a virtual capital flat behind
# s
#
#
#
#
# I
#
# s
# ,
#
#
#
#
#
#
#
#
#
# s,
#
# ks
#
#
# sis
#
#
# sho
# Done. Average cost: 0.9466506838798523
# Starting epoch 39...
# Sampling...
#  Reuter
#      no consumer market rig is 38 cents a share
#  and
#
# art
#
# o.
#
#
# will
#
# th.
#
#
#
#
#
#
#
# owed
#
#
#
# has
#
# Done. Average cost: 0.9460924863815308
# Starting epoch 40...
# Sampling...
#     Speaking to the last unit fell one pct growth this year. Followin
# ,
#
# B
#
#
# o
#
#
# uking
#
#
#
#
#
# o
#
#
# on
#
#
#
# Done. Average cost: 0.9452806711196899
# Starting epoch 41...
# Sampling...
#     The numercial resources bank developed by Michel Inc. "The
#
#
#
# he
#
#
# on
#
#
# an
#
# air,
#
# qt sa
#
#
#
#
#
#
#
#
#
#
# Done. Average cost: 0.9445144534111023
# Starting epoch 42...
# Sampling...
#     Nine mths
#  264.9 mln vs 475.8 mln
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# w
#
#
#
#
#
#
#
#
#
#
#
#
# ,
#
# he
#
#
# ef
#
# ous
# ,
#
# he
#
# Done. Average cost: 0.9437675476074219
# Starting epoch 43...
# Sampling...
#     NOTE: 1987 net both pensions exclude loan paper company
#
# al
#
#
#
# ute
#
#
#
#
#
# an
#
# ell
#
# .
# .....
#
#
#
#
# plas
# Done. Average cost: 0.9430399537086487
# Starting epoch 44...
# Sampling...
#     vyt drop on debt plus if fears will get, natural gas until
#
#
# gulf
#
#
# a
#
# zug
#
# is
#
# us
#
# se
# backers
#
# h
# Done. Average cost: 0.9425793886184692
# Starting epoch 45...
# Sampling...
#     Net 3,733,000 vs 3,671,000
#
#
#
#
#
#
#
#
#
#
# s
#
#
#
#
#
#
#
#
#
#
#
#
#
# >
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Done. Average cost: 0.9420560002326965
# Starting epoch 46...
# Sampling...
#     Avg shrs 50,8378,105 vs 8,893,896
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# >
#
#
#
#
#
#
#
#
#
#
#
#
#
# >
#
# is
#
#
#
#
# zi
# berg
#
#
# ,
#
# has
#
# Done. Average cost: 0.9415687322616577
# Starting epoch 47...
# Sampling...
#     Net 4,200,000 vs 587,000
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ^
#
#
#
#
# >
#
# i
#
#
#
# is
#
# on
#
#
#
#
# Luc
#
#
# a
#
# on
#
#
#
#
#
#
#
# Done. Average cost: 0.9411517977714539
# Starting epoch 48...
# Sampling...
#  Reuter
#
# culls now operate the two trading plant and the
#
#
#
#
#
#
# A.
# .
#
#
#
#
#
#
#
#
# .
#
#
#
#
#
#
# would
#
# widenn
#
#
#
#
# Done. Average cost: 0.9406662583351135
# Starting epoch 49...
# Sampling...
#     NOTE: Crazy Federal Savings and Loan Association and group
#
# on
#
# eight
# seos
#
# ate.
# ....
#
#
# busen
#
#
#
#
# Done. Average cost: 0.9401299357414246
# Starting epoch 50...
# Sampling...
#     The company said the company said Belgian Federal Reserve is
# at
#
#
# week
#
#
# I
#
#
#
#
#
# A.
#
#
#
#
#
#
#
# was
# ,
#
#
# Done. Average cost: 0.9399086236953735
# Starting epoch 51...
# Sampling...
#  Reuter
#
# Hasshiff said
#  has been dismissed Ontario as a golden
#
# e on
# was
# ."
#
#
# C
#
#
#
#
#
# shan
# forth
#
#
#
# ca
# Done. Average cost: 0.9395421743392944
# Starting epoch 52...
# Sampling...
#  Reuter
#          nil    nil
#
#
# exclubicle first
#
# has
# ,
#
# has
# )
#
#
#
# who
#
#
# has
# .
#
#
#
#
#
#
#
#
#
#
#
# who
#
# has,
# Done. Average cost: 0.9389451742172241
# Starting epoch 53...
# Sampling...
#     NOTE: 1981 year net excludes a year earlier blaoked by the
#
# 's
#
#
#
# s
#
# enger
#
#
# plase
# ,
#
# Belt.
#
#
#
#
#
#
# Done. Average cost: 0.938228189945221
# Starting epoch 54...
# Sampling...
#     NOTE: 1986 vs 20.0p
#  mature 46 mln megaizanly
#
# out
#
#
# erge
#
#
#
#
#
#
#
#
#
#
# ,
#
# when
#
#
#
# on
#
#
#
#
#
#
# has
#
#
#
# ho
# Done. Average cost: 0.9376952648162842
# Starting epoch 55...
# Sampling...
#     Shr 1.83 dlrs vs 1.3738 dlrs
#
#
#
#
# ,
#
#
#   5.00 pct following
#
# wi
# her
#
# zed
#
#
# shim
#
#
#
#
#
# owe
#
#
#
#
# o
# Done. Average cost: 0.9374004006385803
# Starting epoch 56...
# Sampling...
#     Nigeria's hydre, Sir Form Iran underwriting after Leun's
#
#
# spirise
#
#
#
#
#
# 's
#
# ,
#
# hammers,
#
# harges
#
#
# Done. Average cost: 0.9369684457778931
# Starting epoch 57...
# Sampling...
#     Pay lahge
#  upgrade 10 pct, a proposed 58 minus trade
#
#
#
#
#
#
#
#
#
#
#
#
# ,
#
# ."
# fas
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Done. Average cost: 0.9366891384124756
# Starting epoch 58...
# Sampling...
#     NOTE: 1987 nine mths restructure and substantially comparable
#
#
#
#
#
#
#
# on
#
#
# ,
#
# Jack
#
# el
# ,
#
#
# I
#
# It,
#
# Done. Average cost: 0.9362928867340088
# Starting epoch 59...
# Sampling...
#     Six month basis 123.7 billion vs 901.4 mln
#
#  nil
# ,
#
# 1,
# 50
#
#
#
#
#
#
#
#
# ,
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Done. Average cost: 0.9358681440353394
# Starting epoch 60...
# Sampling...
#      Nixken Mortgage seisco reschedules the rate of one
#
#
#
#
#
#
#
#
# oa
# s
#
# th
#
#
#
#
# in
#
#
# Pecsa Manufacturing
# Done. Average cost: 0.9354411959648132
# Starting epoch 61...
# Sampling...
#     Shr 2.09 dlrs vs 1.58 dlrs
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# >, which
# hase
#  said
#
#
# he
#
#
#
# "
#
# has
#
#
#
# stomed
#
#
#
# ha
# Done. Average cost: 0.9351357221603394
# Starting epoch 62...
# Sampling...
#     Shr 2.04 dlrs vs 2.45 dlr
#
# fum 91.04   644.42   88.53
#
#
#    din
# 1
#
#
#
#
#
#
#
#
#
# G
#
#
# oc
#
#
#
#
#
#
# Ll
#
#
#
#
# L
#
# Done. Average cost: 0.9347289204597473
# Starting epoch 63...
# Sampling...
#     Net profit 320,000 vs loss 343,000
#
#
#
#
#
#
#
#
#
# s
#
#
# i
#
#
#
# has
#
#
#
# welg
# .
#
#
#
#
#
#
# owas
#
# ow
#
#
#
#
#
# ,
#
# he
#
#
#
# e
# Done. Average cost: 0.9344644546508789
# Starting epoch 64...
# Sampling...
#     Shr 2.83 dlrs vs 67 cts
#
#
# ll
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ATA> is just
# , quoted
#
#
#
#
#
# way,
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# O
# Done. Average cost: 0.9341164827346802
# Starting epoch 65...
# Sampling...
#     Net 2,402,000 vs 1,977,000
#
#
#
#
#
#
#
#
#
#
# s
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# w
#
#
#
#
#
# They
#
# will pr
# Done. Average cost: 0.9339448809623718
# Starting epoch 66...
# Sampling...
#     Net 23.6 mln vs 14.7 mln
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# >
#
#
#
#
#
#
# o
#
#
# hoo
#
#
# one
# .
#
# On
#
#
# was
# us
#
#
#
#
#
# Done. Average cost: 0.9336564540863037
# Starting epoch 67...
# Sampling...
#  Exports     NT  570.0    (14,272.70))
#
# on
#
#
#
# Use
#
#
#
#
#
#
#
# Howa)
#
#
#
#
#
#
#
#
#
#
#
# )
#
# ec
#
#
#
#
#
#
# ot
#
#
# he
# moch
#
#
#
# Done. Average cost: 0.9332453012466431
# Starting epoch 68...
# Sampling...
#     Net profit 68,572 vs loss 1.45 billion
#
#
#
#
#
#
#
#
#
#
#
#
#
# w
#
#
#
#
#
#
#
#
#
#
#
#
#
# ,
#
# X
# ),
#
# had
# how with
# y
#
#
# sha
#
# Done. Average cost: 0.9331204295158386
# Starting epoch 69...
# Sampling...
#     Japanese finance minister Allegray has a direct company he
# ful
# "
#
# has
#
# ok
#
#
#
# al
#
#
#
# it
#
# ons
# an ant
# Done. Average cost: 0.9326567053794861
# Starting epoch 70...
# Sampling...
#     NOTE: Prior year beginning the same and six-date domestic
#
# on
#
# ess
# noll
#
#
# on
#
# ensly
# wide Nine
# Vaz
# Done. Average cost: 0.9322047233581543
# Starting epoch 71...
# Sampling...
#     Senate Marketing 5000 futures trade to the country's about
#
#
# hold
#
# a
# on
#
#
# spen
# er
#
# ens
#
# ope.
#
#
#
# T
# Done. Average cost: 0.9317554831504822
# Starting epoch 72...
# Sampling...
#   Seven dated Division Equirold of Illinois, Vining told a news
# of
#
#
#
# ...
# , a
#
# uti
# fictate
#
# and.
#
#
# a
#
# Done. Average cost: 0.9313622117042542
# Starting epoch 73...
# Sampling...
#     Until the four-hour-bearing futures producers and was
# s
#
# has
#
#
#
#
# IBL.
#
#
#
#
#
#
#
# said
#
#
#
# A
# >'s
#
#
#
#
# ou
# Done. Average cost: 0.931073784828186
# Starting epoch 74...
# Sampling...
#     "The SEC issued by Michael William B reform sales and
# usont
#
# on
#
#
#
# he
#
#
#
# one.
#
#
# is
#
#
# on
# phasing
# e
# Done. Average cost: 0.9307524561882019
# Starting epoch 75...
# Sampling...
#     Net 1,562,868 vs 772,904
#
#
#
#
#
#
#
#
#
#
#
# s
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# >
#
# us
#
#
# on
#
#
#
#
# on
# U
#
#
#
#
#
#
#
# on
#
#
#
#
#
#
# ,
#
#
#
#
# U
# Done. Average cost: 0.9305776357650757
# Starting epoch 76...
# Sampling...
#     "At third countries have celler policies that Barry Citous of
# .
#
#
#
#
#
#
# on
#
#
# see
#
#  the
#
#
#
#
#
#
#
# ous
# s
# Done. Average cost: 0.9303094744682312
# Starting epoch 77...
# Sampling...
#     Net 13.1 mln vs 11.0 mln
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# s>,
#
#
#
#  YUAIN -
# PCE
#  Genezi
# aum
#
#
#
# oo
#
# it
#
#
#
#
#
#
#
#
#
# W,
#
# Done. Average cost: 0.9300311207771301
# Starting epoch 78...
# Sampling...
#     Avg shrs 47.6 mln vs 30.2p month
#
#
#
# odle
#
#
# on
#
#
# as
#
#
# sped
#
#
# Led
#
#
#
# has
#
#
#
#
# Eurodone
#
#
#
# on
#
#
#
#
#
#
#
#
# Done. Average cost: 0.929811418056488
# Starting epoch 79...
# Sampling...
#  Reuter
#
#       04
# 7         04/09 298 mln
#  Nil
#
# week maturity
#
#
#
#
# owe
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# s
#
# ,
#
# Mutsuo
# Done. Average cost: 0.9295457601547241
# Starting epoch 80...
# Sampling...
#     Net 2,202,000 vs 1,736,000
#
#
#
#
#
#
#
#
#
#
#
#
# s
#
#
#
#
#
#
#
#
#
# K
# ,
#
# termet
#
#
#
# .
#
#
#
#
#
#
#
# s
#
#
# es
#
# sees
#
# s
#
# quick
#
# Done. Average cost: 0.9292922019958496
# Starting epoch 81...
# Sampling...
#     Net 45,875,000 vs 26,489,000
# 0
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# >
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Done. Average cost: 0.9290713667869568
# Starting epoch 82...
# Sampling...
#  Reuter
#
#
# up is subject to spapuging and intention
#
# Resources
#
#
# one
#
#
#
#
#
#
# op
#
# eebur.
#
#
# shed
#
#
# s
#
# bit
#
# Done. Average cost: 0.9289442300796509
# Starting epoch 83...
# Sampling...
#     He said the companies were surpused by accessoutle market
# powers
#  a
#
#
#
#
# manage
#
#
# on
# fats
#
# ut
#
#
# om
# Done. Average cost: 0.9286448359489441
# Starting epoch 84...
# Sampling...
#     Nine Mths
#
# haffened of 98 mln dlrs, plus the panel's agent, but
#
#
# on
#
# ent
# west
#
#
#
#
# aid
#
#
#
# has
#
#
#
#
# Done. Average cost: 0.9284607768058777
# Starting epoch 85...
# Sampling...
#     NOTE:1987 includes a U.S. Soviet project as the House
# was
#
#
#
#
# half
#
# esn
#
#
# it
#
#
#
# pelled
#
#
#
#
#
#
# had
#
# Done. Average cost: 0.9283246994018555
# Starting epoch 86...
# Sampling...
#     Shr 44 cts vs 23 cts
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# >
#
#
#
#
#
#
#
#
#
#
#
# ow
#
#
#
#
# on
#
#
#
# on
#
#
#
#
#
#
# wer
#
#
#
#
#
#
#
#
#
#
#
# Done. Average cost: 0.9278547763824463
# Starting epoch 87...
# Sampling...
#  REUTER
#
#
#
# .
#
#
#
#
# Paal said.
#  Soybean
#
#
# enter
#
# ends
#
# entation
#
# solies
#
#
# on
# .
#
#
# it
#
# shates
#
# us
#
# op
#
# Done. Average cost: 0.927716851234436
# Starting epoch 88...
# Sampling...
#     He said its aboliting Secretary Paul Economy had no talk
#
#
# th
#
#
#
#
# in
#
#
# ume).
#
#
#
# I
#
# a
#
# ors make
#
# e
# Done. Average cost: 0.9274585247039795
# Starting epoch 89...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-8024f193f577> in <module>()
#       1 model = RnnLm(hidden_size=hidden_size, num_layers=num_layers, batch_size=batch_size, num_epochs=num_epochs,
#       2               num_tokens=100, charlevel=True, cell_type="gru")
# ----> 3 model.train("reuters_parsed.txt")
#
# <ipython-input-5-b2f51e378aac> in train(self, filename)
#     134         self.fit_data(filename)
#     135         self.construct_graph()
# --> 136         self.run_session()
#     137
#     138     def sample(self, token, num_tokens=None, session=None):
#
# <ipython-input-5-b2f51e378aac> in run_session(self)
#     118                     self.print_("\tStarting batch {}...".format(batch_number))
#     119                     start = datetime.now()
# --> 120                     batch_cost, _ = session.run([self.loss, self.optimizer], feed_dict=feedDict)
#     121                     batch_costs.append(batch_cost)
#     122                     self.print_("\tDone batch {} in {} seconds.".format(batch_number,
#
# /usr/local/lib/python3.4/dist-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     715     try:
#     716       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 717                          run_metadata_ptr)
#     718       if run_metadata:
#     719         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/lib/python3.4/dist-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     913     if final_fetches or final_targets:
#     914       results = self._do_run(handle, final_targets, final_fetches,
# --> 915                              feed_dict_string, options, run_metadata)
#     916     else:
#     917       results = []
#
# /usr/local/lib/python3.4/dist-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#     963     if handle is None:
#     964       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# --> 965                            target_list, options, run_metadata)
#     966     else:
#     967       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /usr/local/lib/python3.4/dist-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#     970   def _do_call(self, fn, *args):
#     971     try:
# --> 972       return fn(*args)
#     973     except errors.OpError as e:
#     974       message = compat.as_text(e.message)
#
# /usr/local/lib/python3.4/dist-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#     952         return tf_session.TF_Run(session, options,
#     953                                  feed_dict, fetch_list, target_list,
# --> 954                                  status, run_metadata)
#     955
#     956     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %% [markdown]
# Видно, что RNN с мой GRU обучается быстрее, чем RNN c LSTM, наверное из-за того, что модель более простая. Кстати забавно, что charlevel-модель хорошо научилась выделять места где smth vs smth, даже зачастую с правильными единицами измерения по обе стороны от vs :) Еще я тестировала на русском датасете более узкой тематики, там получались более хорошие результаты. Еще они были смешнее, из-за того что char-level модель может легко менять окончания итп.
